# %% [markdown]
# ### Tumbling windows
#
# - Divide 1 hour ***Vital (PIP, PEEP, eVT, OSI)*** and ***Waveform (Flow)*** signals into $\color{yellow}{\text{six}}$ non-overlapping tumbling windows $\color{yellow}{\text{ten}}$ minutes in length.

# %%
## Waveform 1st

import pandas as pd
import os

# Define the directory path
directory = "/nfs/turbo/med-kayvan-lab/Projects/PARDS/02-Data/TRAPPARDS/WaveformData/01_Waveform_Raw_248_1st/FTandBBF_243_1st/"

# Create a new directory to store modified files
new_directory = os.path.join(directory, "TWs_243_1st")
os.makedirs(new_directory, exist_ok=True)

# Loop through each CSV file in the directory
for filename in os.listdir(directory):
    if filename.endswith(".csv"):
        # Read the CSV file into a DataFrame
        filepath = os.path.join(directory, filename)
        df = pd.read_csv(filepath)
        
        # Attempt to convert 'Time' column to datetime format
        try:
            df['Time'] = pd.to_datetime(df['Time'], format='%Y-%m-%d %H:%M:%S.%f')
        except Exception as e:
            print(f"Error converting 'Time' column to datetime format in file: {filename}")
            print(e)
            continue  # Skip further processing for this file if an error occurs
        
        # Add the "Tumbling_window" column
        df["Tumbling_window"] = 0  # Initialize with zeros
        
        # Calculate the tumbling window values based on the "Time" column
        window_size = pd.Timedelta(minutes=10)
        window_number = 1
        current_window_start = df["Time"].iloc[0]
        for i, time in enumerate(df["Time"]):
            if time >= current_window_start + window_size:
                window_number += 1
                current_window_start = time
            df.at[i, "Tumbling_window"] = window_number
        
        # Save the modified DataFrame to a new CSV file in the new directory
        new_filepath = os.path.join(new_directory, filename)
        df.to_csv(new_filepath, index=False)

# %%
## Vital 1st

import pandas as pd
import os

# Define the directory path
directory = "/nfs/turbo/med-kayvan-lab/Projects/PARDS/02-Data/TRAPPARDS/VitalData/01_Vital_Raw_282_1st/OSI_285_1st/"
# print(len(os.listdir(directory)))

# Create a new directory to store modified files
new_directory = os.path.join(directory, "TWs_285_1st")
os.makedirs(new_directory, exist_ok=True)

# Loop through each CSV file in the directory
for filename in os.listdir(directory):
    if filename.endswith(".csv"):
        # Read the CSV file into a DataFrame
        filepath = os.path.join(directory, filename)

        # Check if the file is empty before loading
        if os.path.getsize(filepath) == 0:
            print(f"Skipping empty file: {filename}")
            continue
        
        # Read the CSV file into a DataFrame
        try:
            df = pd.read_csv(filepath)
            if df.empty:
                print(f"Skipping file with no data: {filename}")
                continue
        except pd.errors.EmptyDataError:
            print(f"File {filename} is empty or cannot be read.")
            continue

        # Attempt to convert 'Time' column to datetime format
        df['Time'] = pd.to_datetime(df['Time'], format='%Y-%m-%d %H:%M:%S.%f')
        
        # Add the "Tumbling_window" column
        df["Tumbling_window"] = 0  # Initialize with zeros
        
        # Calculate the tumbling window values based on the "Time" column
        window_size = pd.Timedelta(minutes=10)
        window_number = 1
        current_window_start = df["Time"].iloc[0]
        for i, time in enumerate(df["Time"]):
            if time >= current_window_start + window_size:
                window_number += 1
                current_window_start = time
            df.at[i, "Tumbling_window"] = window_number
        
        # Save the modified DataFrame to a new CSV file in the new directory
        new_filepath = os.path.join(new_directory, filename)
        df.to_csv(new_filepath, index=False)
# Out:
# File 833391_20230728_00_Vital_1st.csv is empty or cannot be read.

# %%
## Vital 12th

import pandas as pd
import os

# Define the directory path
directory = "/nfs/turbo/med-kayvan-lab/Projects/PARDS/02-Data/TRAPPARDS/VitalData/02_Vital_Raw_226_12th/OSI_259_12th/"

# Create a new directory to store modified files
new_directory = os.path.join(directory, "TWs_259_12th")
os.makedirs(new_directory, exist_ok=True)

# Loop through each CSV file in the directory
for filename in os.listdir(directory):
    if filename.endswith(".csv"):
        # Read the CSV file into a DataFrame
        filepath = os.path.join(directory, filename)

        # Check if the file is empty before loading
        if os.path.getsize(filepath) == 0:
            print(f"Skipping empty file: {filename}")
            continue
        
        # Read the CSV file into a DataFrame
        try:
            df = pd.read_csv(filepath)
            if df.empty:
                print(f"Skipping file with no data: {filename}")
                continue
        except pd.errors.EmptyDataError:
            print(f"File {filename} is empty or cannot be read.")
            continue

        # Attempt to convert 'Time' column to datetime format
        df['Time'] = pd.to_datetime(df['Time'], format='%Y-%m-%d %H:%M:%S.%f')
        
        # Add the "Tumbling_window" column
        df["Tumbling_window"] = 0  # Initialize with zeros
        
        # Calculate the tumbling window values based on the "Time" column
        window_size = pd.Timedelta(minutes=10)
        window_number = 1
        current_window_start = df["Time"].iloc[0]
        for i, time in enumerate(df["Time"]):
            if time >= current_window_start + window_size:
                window_number += 1
                current_window_start = time
            df.at[i, "Tumbling_window"] = window_number
        
        # Save the modified DataFrame to a new CSV file in the new directory
        new_filepath = os.path.join(new_directory, filename)
        df.to_csv(new_filepath, index=False)
# Out:
# File 1223951_20240516_13_Vital_12th.csv is empty or cannot be read.

# %%
import os
import pandas as pd

# Path to the file in question
file_path = "/nfs/turbo/med-kayvan-lab/Projects/PARDS/02-Data/TRAPPARDS/VitalData/02_Vital_Raw_226_12th/OSI_259_12th/1223951_20240516_13_Vital_12th.csv"

try:
    # Attempt to read the file
    df = pd.read_csv(file_path)
    
    # Check if there’s data and if it meets the 1-hour duration requirement
    if not df.empty:
        # Assuming there's a timestamp or time column to calculate the duration
        # Replace 'Time' with the actual column name containing the time info
        if 'Time' in df.columns:
            df['Time'] = pd.to_datetime(df['Time'], errors='coerce')
            duration = (df['Time'].max() - df['Time'].min()).seconds / 3600
            
            if duration < 1:
                print(f"Warning: File '{file_path}' contains less than 1 hour of data.")
            else:
                print(f"File '{file_path}' read successfully with sufficient data.")
        else:
            print(f"File '{file_path}' read successfully, but 'Time' column not found for duration check.")
    else:
        print(f"File '{file_path}' is empty.")
except Exception as e:
    print(f"Error reading file '{file_path}': {e}")
# Out:
# Error reading file '/nfs/turbo/med-kayvan-lab/Projects/PARDS/02-Data/TRAPPARDS/VitalData/02_Vital_Raw_226_12th/OSI_259_12th/1223951_20240516_13_Vital_12th.csv': No columns to parse from file
