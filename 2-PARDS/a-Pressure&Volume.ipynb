# %% [markdown]
# ### The relationship between Pressure and Volume under the setting of Pressure Control Mode
#
# - PIP and TV are directly related. One of them is set on the vent and the other will vary. ***How much it varies is an open question*** and we could write our first descriptive paper on this. We would need to find the vent settings in Sickbay first. ***Right now, a physician evaluates the TV (if PIP is set on vent) at 8am, but the amount of actual variation and amount of time in the desired range is actually accomplished.***
#
# - PIP < 28 mbar(cmH2O) and TV between 6 mL/kg and 8 mL/kg
#
# - Will this change per type of vent?
#
# - Eventually we could compare this with adult vent waveforms too (ie Mike S.)

# %% [markdown]
# Step 1: Control Mode Categorical
#
# - Pressure Control (or Volume Guarantee) Mode, if column names contains:
#
#     - CDGR: "CDGR - Set: PEEP L" & ***"CDGR - Set: Pinsp"***
#     - AVEAA: "AVEA - Set: PEEP" & ***"AVEA - Set: Pinsp"***
#
# - Volume Control Mode, if column names contains:
#
#     - CDGR: "CDGR -Set: PEEP L" & ***"CDGR - Set: VT in mL"***
#     - AVEAA: "AVEA - Set: PEEP" & ***"AVEA - Set: iVT"***

# %%
## 58_CDGR_39_1st cohort:

import os
import pandas as pd

# Directory containing the CSV files
directory = "/nfs/turbo/med-kayvan-lab/Projects/PARDS/02-Data/02-EVENTS/a-CDGR+AVEAA+SVU(58)_20240205/a-58_CDGR_39_1st/a-58_CDGR_39_1st_OSI/a-58_CDGR_39_1st_FTandBBF/a-58_CDGR_39_1st_No55/a-58_CDGR_39_1st_tw/a-58_CDGR_39_1st_cleaned/"

# List to store the results
results = []

# Loop through all files in the directory
for filename in os.listdir(directory):
    if filename.endswith(".csv"):
        filepath = os.path.join(directory, filename)
        try:
            # Read the CSV file into a DataFrame
            df = pd.read_csv(filepath)
            # Check if both required columns are present
            # if 'CDGR - Set: PEEP L' in df.columns and 'CDGR - Set: Pinsp' in df.columns:
            if 'CDGR - Set: Pinsp' in df.columns:
                mode_category = "Pressure Control (or Volume Guarantee) Mode"
            # elif 'CDGR - Set: PEEP L' in df.columns and 'CDGR - Set: VT in mL' in df.columns:
            elif 'CDGR - Set: VT in mL' in df.columns:
                mode_category = "Volume Control Mode"
            else:
                mode_category = "Unknown"

            # Append the result to the list
            results.append({'File Name': filename, 'Mode Category': mode_category})
        except Exception as e:
            print(f"Error processing file '{filename}': {str(e)}")

# Create a DataFrame from the results list
result_df = pd.DataFrame(results)

# Save the DataFrame to a CSV file
output_file_name = "Mode_Cat_CDGR_58.csv"
result_df.to_csv(output_file_name, index=False)
# Out:
# Error processing file 'a_58_CDGR_39_1st (18).csv': Error tokenizing data. C error: Calling read(nbytes) on source failed. Try engine='python'.

# %%
## 58_CDGR_39_1st cohort:

import pandas as pd
import os
import shutil

# Read the CSV file
csv_file = "Mode_Cat_CDGR_58.csv"
data = pd.read_csv(csv_file)

# Filter rows where mode_category is "Pressure Control (or Volume Guarantee) Mode"
filtered_data = data[data['Mode Category'] == 'Pressure Control (or Volume Guarantee) Mode']

# Define the source and destination paths
## 24hrs version:
source_path = "/nfs/turbo/med-kayvan-lab/Projects/PARDS/02-Data/02-EVENTS/a-CDGR+AVEAA+SVU(58)_20240205/a-58_CDGR_39_24hrs/"
destination_path = "/nfs/turbo/med-kayvan-lab/Projects/PARDS/02-Data/02-EVENTS/PvsV_24hrs_Raw/CDGR/"

# ## Raw version:
# source_path = "/nfs/turbo/med-kayvan-lab/Projects/PARDS/02-Data/02-EVENTS/a-CDGR+AVEAA+SVU(58)_20240205/a-58_CDGR_39_1st/a-58_CDGR_39_1st_OSI/"
# destination_path = "/nfs/turbo/med-kayvan-lab/Projects/PARDS/02-Data/02-EVENTS/PvsV_1hr_Raw/CDGR/"

# ## Cleaned version:
# source_path = "/nfs/turbo/med-kayvan-lab/Projects/PARDS/02-Data/02-EVENTS/a-CDGR+AVEAA+SVU(58)_20240205/a-58_CDGR_39_1st/a-58_CDGR_39_1st_OSI/a-58_CDGR_39_1st_FTandBBF/a-58_CDGR_39_1st_No55/a-58_CDGR_39_1st_tw/a-58_CDGR_39_1st_cleaned/"
# destination_path = "/nfs/turbo/med-kayvan-lab/Projects/PARDS/02-Data/02-EVENTS/PvsV_1hr_Cleaned/CDGR/"

# Create the destination directory if it doesn't exist
if not os.path.exists(destination_path):
    os.makedirs(destination_path)

# Copy relevant files to the new folder
for index, row in filtered_data.iterrows():
    # file_name = row['File Name']
    file_name = row['File Name 2']
    source_file_path = os.path.join(source_path, file_name)
    destination_file_path = os.path.join(destination_path, file_name)
    shutil.copy(source_file_path, destination_file_path)

print("Files copied successfully.")
# Out:
# Files copied successfully.

# %%
## 151_CDGR_11_1st cohort:

import os
import pandas as pd

directory = "/nfs/turbo/med-kayvan-lab/Projects/PARDS/02-Data/02-EVENTS/b-CDGR+AVEAA+SVU(151)_20240205/b-151_CDGR_11_1st/b-151_CDGR_11_1st_OSI/b-151_CDGR_11_1st_FTandBBF/b-151_CDGR_11_1st_No55/b-151_CDGR_11_1st_tw/b-151_CDGR_11_1st_cleaned/"

# List to store the results
results = []

# Loop through all files in the directory
for filename in os.listdir(directory):
    if filename.endswith(".csv"):
        filepath = os.path.join(directory, filename)
        try:
            # Read the CSV file into a DataFrame
            df = pd.read_csv(filepath)
            # Check if both required columns are present
            # if 'CDGR - Set: PEEP L' in df.columns and 'CDGR - Set: Pinsp' in df.columns:
            if 'CDGR - Set: Pinsp' in df.columns:
                mode_category = "Pressure Control (or Volume Guarantee) Mode"
            # elif 'CDGR - Set: PEEP L' in df.columns and 'CDGR - Set: VT in mL' in df.columns:
            elif 'CDGR - Set: VT in mL' in df.columns:
                mode_category = "Volume Control Mode"
            else:
                mode_category = "Unknown"

            # Append the result to the list
            results.append({'File Name': filename, 'Mode Category': mode_category})
        except Exception as e:
            print(f"Error processing file '{filename}': {str(e)}")

# Create a DataFrame from the results list
result_df = pd.DataFrame(results)

# Save the DataFrame to a CSV file
output_file_name = "Mode_Cat_CDGR_151.csv"
result_df.to_csv(output_file_name, index=False)

# %%
## 151_CDGR_11_1st cohort:

import pandas as pd
import os
import shutil

# Read the CSV file
csv_file = "Mode_Cat_CDGR_151.csv"
data = pd.read_csv(csv_file)

# Filter rows where mode_category is "Pressure Control (or Volume Guarantee) Mode"
filtered_data = data[data['Mode Category'] == 'Pressure Control (or Volume Guarantee) Mode']

# Define the source and destination paths
## 24hrs version:
source_path = "/nfs/turbo/med-kayvan-lab/Projects/PARDS/02-Data/02-EVENTS/b-CDGR+AVEAA+SVU(151)_20240205/b-151_CDGR_11_24hrs/"
destination_path = "/nfs/turbo/med-kayvan-lab/Projects/PARDS/02-Data/02-EVENTS/PvsV_24hrs_Raw/CDGR/"

# ## Raw version:
# source_path = "/nfs/turbo/med-kayvan-lab/Projects/PARDS/02-Data/02-EVENTS/b-CDGR+AVEAA+SVU(151)_20240205/b-151_CDGR_11_1st/b-151_CDGR_11_1st_OSI/"
# destination_path = "/nfs/turbo/med-kayvan-lab/Projects/PARDS/02-Data/02-EVENTS/PvsV_1hr_Raw/CDGR/"

# ## Cleaned version:
# source_path = "/nfs/turbo/med-kayvan-lab/Projects/PARDS/02-Data/02-EVENTS/b-CDGR+AVEAA+SVU(151)_20240205/b-151_CDGR_11_1st/b-151_CDGR_11_1st_OSI/b-151_CDGR_11_1st_FTandBBF/b-151_CDGR_11_1st_No55/b-151_CDGR_11_1st_tw/b-151_CDGR_11_1st_cleaned/"
# destination_path = "/nfs/turbo/med-kayvan-lab/Projects/PARDS/02-Data/02-EVENTS/PvsV_1hr_Cleaned/CDGR/"

# Create the destination directory if it doesn't exist
if not os.path.exists(destination_path):
    os.makedirs(destination_path)

# Copy relevant files to the new folder
for index, row in filtered_data.iterrows():
    # file_name = row['File Name']
    file_name = row['File Name 2']
    source_file_path = os.path.join(source_path, file_name)
    destination_file_path = os.path.join(destination_path, file_name)
    shutil.copy(source_file_path, destination_file_path)

print("Files copied successfully.")
# Out:
# Files copied successfully.

# %%
## 58_AVEAA_4_1st cohort:

import os
import pandas as pd

directory = "/nfs/turbo/med-kayvan-lab/Projects/PARDS/02-Data/02-EVENTS/a-CDGR+AVEAA+SVU(58)_20240205/a-58_AVEAA_4_1st/a-58_AVEAA_4_1st_OSI/a-58_AVEAA_4_1st_FTandBBF/a-58_AVEAA_4_1st_No55/a-58_AVEAA_4_1st_tw/a-58_AVEAA_4_1st_cleaned/"

# List to store the results
results = []

# Loop through all files in the directory
for filename in os.listdir(directory):
    if filename.endswith(".csv"):
        filepath = os.path.join(directory, filename)
        try:
            # Read the CSV file into a DataFrame
            df = pd.read_csv(filepath)
            # Check if both required columns are present
            # if 'AVEA - Set: PEEP' in df.columns and 'AVEA - Set: Pinsp' in df.columns:
            if 'AVEA - Set: Pinsp' in df.columns:
                mode_category = "Pressure Control (or Volume Guarantee) Mode"
            # elif 'AVEA - Set: PEEP' in df.columns and 'AVEA - Set: iVT' in df.columns:
            elif 'AVEA - Set: iVT' in df.columns:
                mode_category = "Volume Control Mode"
            else:
                mode_category = "Unknown"

            # Append the result to the list
            results.append({'File Name': filename, 'Mode Category': mode_category})
        except Exception as e:
            print(f"Error processing file '{filename}': {str(e)}")

# Create a DataFrame from the results list
result_df = pd.DataFrame(results)

# Save the DataFrame to a CSV file
output_file_name = "Mode_Cat_AVEAA_58.csv"
result_df.to_csv(output_file_name, index=False)

# %%
## 58_AVEAA_4_1st cohort:

import pandas as pd
import os
import shutil

# Read the CSV file
csv_file = "Mode_Cat_AVEAA_58.csv"
data = pd.read_csv(csv_file)

# Filter rows where mode_category is "Pressure Control (or Volume Guarantee) Mode"
filtered_data = data[data['Mode Category'] == 'Pressure Control (or Volume Guarantee) Mode']

# Define the source and destination paths
## 24hrs version:
source_path = "/nfs/turbo/med-kayvan-lab/Projects/PARDS/02-Data/02-EVENTS/a-CDGR+AVEAA+SVU(58)_20240205/a-58_AVEAA_4_24hrs/"
destination_path = "/nfs/turbo/med-kayvan-lab/Projects/PARDS/02-Data/02-EVENTS/PvsV_24hrs_Raw/AVEAA/"

# ## Raw version:
# source_path = "/nfs/turbo/med-kayvan-lab/Projects/PARDS/02-Data/02-EVENTS/a-CDGR+AVEAA+SVU(58)_20240205/a-58_AVEAA_4_1st/a-58_AVEAA_4_1st_OSI/"
# destination_path = "/nfs/turbo/med-kayvan-lab/Projects/PARDS/02-Data/02-EVENTS/PvsV_1hr_Raw/AVEAA/"

# ## Cleaned version:
# source_path = "/nfs/turbo/med-kayvan-lab/Projects/PARDS/02-Data/02-EVENTS/a-CDGR+AVEAA+SVU(58)_20240205/a-58_AVEAA_4_1st/a-58_AVEAA_4_1st_OSI/a-58_AVEAA_4_1st_FTandBBF/a-58_AVEAA_4_1st_No55/a-58_AVEAA_4_1st_tw/a-58_AVEAA_4_1st_cleaned/"
# destination_path = "/nfs/turbo/med-kayvan-lab/Projects/PARDS/02-Data/02-EVENTS/PvsV_1hr_Cleaned/AVEAA/"

# Create the destination directory if it doesn't exist
if not os.path.exists(destination_path):
    os.makedirs(destination_path)

# Copy relevant files to the new folder
for index, row in filtered_data.iterrows():
    # file_name = row['File Name']
    file_name = row['File Name 2']
    source_file_path = os.path.join(source_path, file_name)
    destination_file_path = os.path.join(destination_path, file_name)
    shutil.copy(source_file_path, destination_file_path)

print("Files copied successfully.")
# Out:
# Files copied successfully.

# %%
## 151_AVEAA_4_1st cohort:

import os
import pandas as pd

directory = "/nfs/turbo/med-kayvan-lab/Projects/PARDS/02-Data/02-EVENTS/b-CDGR+AVEAA+SVU(151)_20240205/b-151_AVEAA_4_1st/b-151_AVEAA_4_1st_OSI/b-151_AVEAA_4_1st_FTandBBF/b-151_AVEAA_4_1st_No55/b-151_AVEAA_4_1st_tw/b-151_AVEAA_4_1st_cleaned/"

# List to store the results
results = []

# Loop through all files in the directory
for filename in os.listdir(directory):
    if filename.endswith(".csv"):
        filepath = os.path.join(directory, filename)
        try:
            # Read the CSV file into a DataFrame
            df = pd.read_csv(filepath)
            # Check if both required columns are present
            # if 'AVEA - Set: PEEP' in df.columns and 'AVEA - Set: Pinsp' in df.columns:
            if 'AVEA - Set: Pinsp' in df.columns:
                mode_category = "Pressure Control (or Volume Guarantee) Mode"
            # elif 'AVEA - Set: PEEP' in df.columns and 'AVEA - Set: iVT' in df.columns:
            elif 'AVEA - Set: iVT' in df.columns:
                mode_category = "Volume Control Mode"
            else:
                mode_category = "Unknown"

            # Append the result to the list
            results.append({'File Name': filename, 'Mode Category': mode_category})
        except Exception as e:
            print(f"Error processing file '{filename}': {str(e)}")

# Create a DataFrame from the results list
result_df = pd.DataFrame(results)

# Save the DataFrame to a CSV file
output_file_name = "Mode_Cat_AVEAA_151.csv"
result_df.to_csv(output_file_name, index=False)

# %%
## 151_AVEAA_4_1st cohort:

import pandas as pd
import os
import shutil

# Read the CSV file
csv_file = "Mode_Cat_AVEAA_151.csv"
data = pd.read_csv(csv_file)

# Filter rows where mode_category is "Pressure Control (or Volume Guarantee) Mode"
filtered_data = data[data['Mode Category'] == 'Pressure Control (or Volume Guarantee) Mode']

# Define the source and destination paths
## 24hrs version:
source_path = "/nfs/turbo/med-kayvan-lab/Projects/PARDS/02-Data/02-EVENTS/b-CDGR+AVEAA+SVU(151)_20240205/b-151_AVEAA_4_24hrs/"
destination_path = "/nfs/turbo/med-kayvan-lab/Projects/PARDS/02-Data/02-EVENTS/PvsV_24hrs_Raw/AVEAA/"

# ## Raw version:
# source_path = "/nfs/turbo/med-kayvan-lab/Projects/PARDS/02-Data/02-EVENTS/b-CDGR+AVEAA+SVU(151)_20240205/b-151_AVEAA_4_1st/b-151_AVEAA_4_1st_OSI/"
# destination_path = "/nfs/turbo/med-kayvan-lab/Projects/PARDS/02-Data/02-EVENTS/PvsV_1hr_Raw/AVEAA/"

# ## Cleaned version:
# source_path = "/nfs/turbo/med-kayvan-lab/Projects/PARDS/02-Data/02-EVENTS/b-CDGR+AVEAA+SVU(151)_20240205/b-151_AVEAA_4_1st/b-151_AVEAA_4_1st_OSI/b-151_AVEAA_4_1st_FTandBBF/b-151_AVEAA_4_1st_No55/b-151_AVEAA_4_1st_tw/b-151_AVEAA_4_1st_cleaned/"
# destination_path = "/nfs/turbo/med-kayvan-lab/Projects/PARDS/02-Data/02-EVENTS/PvsV_1hr_Cleaned/AVEAA/"

# Create the destination directory if it doesn't exist
if not os.path.exists(destination_path):
    os.makedirs(destination_path)

# Copy relevant files to the new folder
for index, row in filtered_data.iterrows():
    # file_name = row['File Name']
    file_name = row['File Name 2']
    source_file_path = os.path.join(source_path, file_name)
    destination_file_path = os.path.join(destination_path, file_name)
    shutil.copy(source_file_path, destination_file_path)

print("Files copied successfully.")
# Out:
# Files copied successfully.

# %%
### Volume Control Mode: 5 from 58_CDGR_39_1st cohort

import pandas as pd
import os
import shutil

# Read the CSV file
csv_file = "/nfs/turbo/med-kayvan-lab/Projects/PARDS/02-Data/02-EVENTS/PvsV_24hrs_Raw/Mode_Cat_CDGR_58.csv"
data = pd.read_csv(csv_file)

# Filter rows where mode_category is "Volume Control Mode"
filtered_data = data[data['Mode Category'] == 'Volume Control Mode']

# Define the source and destination paths
## 24hrs version:
source_path = "/nfs/turbo/med-kayvan-lab/Projects/PARDS/02-Data/02-EVENTS/a-CDGR+AVEAA+SVU(58)_20240205/a-58_CDGR_39_24hrs/"
destination_path = "/nfs/turbo/med-kayvan-lab/Projects/PARDS/02-Data/02-EVENTS/PvsV_24hrs_Raw/CDGR_VCM/"

# Create the destination directory if it doesn't exist
if not os.path.exists(destination_path):
    os.makedirs(destination_path)

# Copy relevant files to the new folder
for index, row in filtered_data.iterrows():
    # file_name = row['File Name']
    file_name = row['File Name 2']
    source_file_path = os.path.join(source_path, file_name)
    destination_file_path = os.path.join(destination_path, file_name)
    shutil.copy(source_file_path, destination_file_path)

print("Files copied successfully.")
# Out:
# Files copied successfully.

# %%
### Volume Control Mode: 3 from 151_CDGR_11_1st cohort

import pandas as pd
import os
import shutil

# Read the CSV file
csv_file = "/nfs/turbo/med-kayvan-lab/Projects/PARDS/02-Data/02-EVENTS/PvsV_24hrs_Raw/Mode_Cat_CDGR_151.csv"
data = pd.read_csv(csv_file)

# Filter rows where mode_category is "Volume Control Mode"
filtered_data = data[data['Mode Category'] == 'Volume Control Mode']

# Define the source and destination paths
## 24hrs version:
source_path = "/nfs/turbo/med-kayvan-lab/Projects/PARDS/02-Data/02-EVENTS/b-CDGR+AVEAA+SVU(151)_20240205/b-151_CDGR_11_24hrs/"
destination_path = "/nfs/turbo/med-kayvan-lab/Projects/PARDS/02-Data/02-EVENTS/PvsV_24hrs_Raw/CDGR_VCM/"

# Create the destination directory if it doesn't exist
if not os.path.exists(destination_path):
    os.makedirs(destination_path)

# Copy relevant files to the new folder
for index, row in filtered_data.iterrows():
    # file_name = row['File Name']
    file_name = row['File Name 2']
    source_file_path = os.path.join(source_path, file_name)
    destination_file_path = os.path.join(destination_path, file_name)
    shutil.copy(source_file_path, destination_file_path)

print("Files copied successfully.")
# Out:
# Files copied successfully.

# %% [markdown]
# Step 2: Feature Selection
#
# Ideally: PIP < 28 mbar(cmH2O) and TV between 6 mL/kg and 8 mL/kg
#
# - PIP settings (mbar or cmH2O)
# - Volume vlaues (mL)
# - Patient weight (kg)
# - Time:
#     - 24 hours
#     - 8 am (The physician evaluates the TV (if PIP is set on vent) at 8am)

# %%
# # Load patient weight. However, this code cannot be executed in Great Lakes; it needs to be run under the environment of Sickbay.

# import pandas as pd

# # Load patient IDs and event times from the file
# # events_df = pd.read_csv("sample_events_PID(58_CDGR_39_24hrs).csv")
# # events_df = pd.read_csv("sample_events_PID(151_CDGR_11_24hrs).csv")
# # events_df = pd.read_csv("sample_events_PID(58_AVEAA_4_24hrs).csv")
# events_df = pd.read_csv("sample_events_PID(151_AVEAA_4_24hrs).csv")

# # Create an empty list to store the individual DataFrames
# dfs = []

# # Iterate through the patient IDs and event times
# for index, row in events_df.iterrows():
#     pid = int(row['Patient ID'])
#     starttime = row['Time Start']
#     endtime = row['Time Stop']
    
#     my_logs = sickbay.data.get_patient_log(patient_id=pid, starttime=None, endtime=None)
    
#     # Extract and append the value to a list
#     value_list = []
#     for key in my_logs.keys():
#         if key == 'WEIGHT':   # Change the key name as needed
#             data = my_logs[key]
#             observation = data[0]['observation']
#             value = observation['obs']
#             value *= 0.453592  # 1 lb = 0.453592 kg
#             # Round the weight value to two decimal places
#             value = round(value, 2)
#             value_list.append(value)
    
#     # Calculate the average of the weight values
#     average_value = sum(value_list) / len(value_list) if value_list else None
    
#     # Create a DataFrame with the result for the current patient
#     df = pd.DataFrame({'patient_id': [pid], 'average_value': [average_value]})
    
#     # Append the DataFrame to the list
#     dfs.append(df)

# # Concatenate all DataFrames in the list into a single DataFrame
# result_df = pd.concat(dfs, ignore_index=True)

# # Save the result to a CSV file
# # result_df.to_csv('58_CDGR_39_24hrs_Weights.csv', index=False)
# # result_df.to_csv('151_CDGR_11_24hrs_Weights.csv', index=False)
# # result_df.to_csv('58_AVEAA_4_24hrs_Weights.csv', index=False)
# result_df.to_csv('151_AVEAA_4_24hrs_Weights.csv', index=False)

# %% [markdown]
# - For CDGR: PIP settings = CDGR - Set: Pinsp.

# %%
# CDGR (indiviual sample)

import os
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Directory path
## 24hrs version:
directory_path = "/nfs/turbo/med-kayvan-lab/Projects/PARDS/02-Data/02-EVENTS/PvsV_24hrs_Raw/CDGR/"
## Raw version:
# directory_path = "/nfs/turbo/med-kayvan-lab/Projects/PARDS/02-Data/02-EVENTS/PvsV_1hr_Raw/CDGR/"
# ## Cleaned version:
# directory_path = "/nfs/turbo/med-kayvan-lab/Projects/PARDS/02-Data/02-EVENTS/PvsV_1hr_Cleaned/CDGR/"

output_dir = '/nfs/turbo/med-kayvan-lab/Projects/PARDS/04-Results/PARDS_Descriptive/Supplementary_Figure1'
os.makedirs(output_dir, exist_ok=True)

filename = "a_58_CDGR_39_24hrs (32).csv"
# filename = "b_151_CDGR_11_24hrs (11).csv"

filepath = os.path.join(directory_path, filename)

# Read the CSV file into a pandas DataFrame
df = pd.read_csv(filepath)

df['Time'] = pd.to_datetime(df['Time'], format='%Y-%m-%d %H:%M:%S.%f')

# Rename columns
df.rename(columns={
    'CDGR - Set: Pinsp': 'PIP_Settings',
    'CDGR - Set: PEEP L': 'PEEP_Settings',
    'CDGR - PIP': 'PIP_Actual',
    'CDGR - PEEP': 'PEEP_Actual',
    'CDGR - eVT': 'Tidal_Volume'
}, inplace=True)

## Add PID to the title
# Step 1: Read the CSV file into a DataFrame
df1 = pd.read_csv("/nfs/turbo/med-kayvan-lab/Projects/PARDS/02-Data/02-EVENTS/PvsV_24hrs_Raw/Mode_Cat_CDGR_58.csv")
# df1 = pd.read_csv("/nfs/turbo/med-kayvan-lab/Projects/PARDS/02-Data/02-EVENTS/PvsV_24hrs_Raw/Mode_Cat_CDGR_151.csv")

# Step 2: Check if "filename" matches "File Name 2" and add PID to title
matched_row1 = df1[df1["File Name 2"] == filename]

if not matched_row1.empty:
    pid = matched_row1["PID"].iloc[0]  # Extract PID from filename
    print(pid)
    # title = f'CDGR Ventilator (PID: {pid})'  # Create the title with PID
    title = ""
else:
    # title = "CDGR Ventilator"
    title = ""
    
## Add patient weight according to the PID
# Step 1: Read the CSV file into a DataFrame
df2 = pd.read_csv("/nfs/turbo/med-kayvan-lab/Projects/PARDS/02-Data/02-EVENTS/PvsV_24hrs_Raw/58_CDGR_39_24hrs_Weights.csv")
# df2 = pd.read_csv("/nfs/turbo/med-kayvan-lab/Projects/PARDS/02-Data/02-EVENTS/PvsV_24hrs_Raw/151_CDGR_11_24hrs_Weights.csv")

# Step 2: Check if "filename" matches "File Name 2" and add PID to title
matched_row2 = df2[df2["patient_id"] == pid]

if not matched_row2.empty:
    weight = matched_row2["average_value"].iloc[0]  # Extract PID from filename
    print(weight)
else:
    weight = None

df['TV(mL/kg)'] = df['Tidal_Volume'] / weight
print(df['TV(mL/kg)'])

# Calculate average tidal volume at 8 am
eight_am_data = df[(df['Time'].dt.time >= pd.to_datetime('08:00:00').time()) & 
                   (df['Time'].dt.time <= pd.to_datetime('08:01:00').time())]

# Calculate average tidal volume at 8 am
eight_am_avg = eight_am_data['TV(mL/kg)'].mean()
print(eight_am_avg)

# Create subplots with shared y-axis
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14, 8), sharey=True)

# Add a title for the entire figure including PID
fig.suptitle(title, fontsize=28)

# Violin plot
sns.violinplot(data=df, x='PIP_Settings', y='TV(mL/kg)', hue='PIP_Settings', palette='muted', ax=ax1, legend=False)
ax1.set_xlabel('PIP Settings (mbar)', fontsize=18)
ax1.set_ylabel('Tidal Volume (mL/kg)', fontsize=18)
ax1.set_title('Tidal Volume Distribution across PIP Settings', fontsize=20)

# Add thresholds for Volume
ax1.axhline(y=6, color='g', linestyle='--', linewidth=1, label='Tidal Volume = 6 mL/kg')
ax1.axhline(y=8, color='g', linestyle='--', linewidth=1, label='Tidal Volume = 8 mL/kg')

# Add light green background between the two lines
ax1.axhspan(ymin=6, ymax=8, color='lightgreen', alpha=0.3)

# Get unique PIP_Settings values for the violin plot, remove NaN, and sort from smallest to largest
unique_pip_settings = df['PIP_Settings'].dropna().unique()
unique_pip_settings.sort()
# Get the first row's "PIP_Settings" value from eight_am_data
first_row_pip_settings = eight_am_data.iloc[0]['PIP_Settings']
# Get the index of the first_row_pip_settings value in the unique_pip_settings list
index_of_first_row_pip_settings = list(unique_pip_settings).index(first_row_pip_settings)
# Plot average tidal volume at 8 am as red dot
ax1.scatter([index_of_first_row_pip_settings], [eight_am_avg], color='red', s=50, label=f'Average Tidal Volume at 8 am', zorder=10)
ax1.annotate(f'{eight_am_avg:.2f} mL/kg', xy=(index_of_first_row_pip_settings, eight_am_avg), xytext=(index_of_first_row_pip_settings+0.2, eight_am_avg+1),
             arrowprops=dict(shrink=0.1, width=1.5, headwidth=8, color='red'), color='red', fontsize=18)
ax1.legend(fontsize=16)

ax1.tick_params(axis='x', labelsize=14)
ax1.tick_params(axis='y', labelsize=14)

# Box plot for volume at 8 am
sns.boxplot(data=eight_am_data, x='PIP_Settings', y='TV(mL/kg)', color='cyan', width=0.3, fliersize=0, ax=ax2)
ax2.set_xlabel('PIP Settings (mbar)', fontsize=18)
ax2.set_ylabel('Tidal Volume (mL/kg)', fontsize=18)
ax2.set_title('Tidal Volume at 8 am (1 minute)', fontsize=20)

# Add thresholds for Volume
ax2.axhline(y=6, color='g', linestyle='--', linewidth=1, label='Tidal Volume = 6 mL/kg')
ax2.axhline(y=8, color='g', linestyle='--', linewidth=1, label='Tidal Volume = 8 mL/kg')

# Add light green background between the two lines
ax2.axhspan(ymin=6, ymax=8, color='lightgreen', alpha=0.3)

ax2.legend(fontsize=16)

ax2.tick_params(axis='x', labelsize=14)
ax2.tick_params(axis='y', labelsize=14)

# plt.show()

# Save the plot as an image file
plot_filename = f"{output_dir}/Supp_Fig1_A.png"
# Save the plot as an image file with bbox_inches set to 'tight'
plt.savefig(plot_filename, bbox_inches='tight', dpi=600)
plt.close()  # Close the figure to avoid overlap
# Out:
# 953627
# 2.88
# 0              NaN
# 1              NaN
# 2              NaN
# 3              NaN
# 4              NaN
#            ...
# 64121    12.395834
# 64122    12.083333
# 64123    12.083333
# 64124    11.770834
# 64125    11.180556
# Name: TV(mL/kg), Length: 64126, dtype: float64
# 19.20138854166668

# %%
# PIP Settings v.s Tidal Volume in time series for the Pressure Control Mode cohort
## CDGR (indiviual sample)

import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming df is your existing DataFrame
# Ensure df has 'TV(mL/kg)', 'PIP_Settings', and 'Time' columns

# Extract hour from the Time column
df['Hour'] = df['Time'].dt.hour

# Calculate average PIP Settings per hour
avg_pip_per_hour = df.groupby('Hour')['PIP_Settings'].mean().round().astype(int)  # Round and convert to int

# Calculate average tidal volume at 8 am
eight_am_data = df[(df['Time'].dt.time >= pd.to_datetime('08:00:00').time()) & 
                   (df['Time'].dt.time <= pd.to_datetime('08:01:00').time())]
eight_am_avg = eight_am_data['TV(mL/kg)'].mean()

# Plotting
fig, ax = plt.subplots(figsize=(16, 10))

# Add a title for the entire figure including PID
fig.suptitle(title, fontsize=16)

# Violin plot for Tidal Volume by Hour
sns.violinplot(ax=ax, x='Hour', y='TV(mL/kg)', data=df, inner=None, hue='Hour', palette='muted', legend=False)

# Add thresholds for Volume in violin plot
ax.axhline(y=6, color='g', linestyle='--', linewidth=1, label='Tidal Volume = 6 mL/kg')
ax.axhline(y=8, color='g', linestyle='--', linewidth=1, label='Tidal Volume = 8 mL/kg')

# Add light green background between the two lines
ax.axhspan(ymin=6, ymax=8, color='lightgreen', alpha=0.3)

# # Adding legend for the markers
# ax.legend(title='Legend', bbox_to_anchor=(1, 1), loc='upper left')

# Get unique hours for the x-axis ticks
hours = sorted(df['Hour'].unique())

# Plot average tidal volume at 8 am as red dot
ax.scatter([hours.index(8)], [eight_am_avg], color='red', s=50, label=f'Average Tidal Volume at 8 am')
ax.annotate(f'{eight_am_avg:.2f} mL/kg', xy=(hours.index(8), eight_am_avg), xytext=(hours.index(8) + 0.2, eight_am_avg + 1),
             arrowprops=dict(shrink=0.1, width=1.5, headwidth=8, color='red'), color='red', fontsize=12)

# Add legend
ax.legend()

# Add a title for the violin plot
ax.set_title('Tidal Volume by Hour', fontsize=16, pad=18)  # Increase pad to adjust title position

# Title and labels for the violin plot
ax.set_ylabel('Tidal Volume (mL/kg)')
ax.set_xlabel('Hour')
# # Adjust the position of the x-axis label
# ax.xaxis.set_label_coords(0.5, 0.05)

# Create custom labels for the x-axis
custom_labels = ['{}am'.format(hour) if hour < 12 else '{}pm'.format(hour - 12) for hour in range(24)]

# Set custom x-axis labels (bottom x-axis)
ax.set_xticks(range(24))
ax.set_xticklabels(custom_labels)

# # Hide x-axis ticks
# ax.xaxis.set_ticks([])

# Custom function to format table cells
def format_table_cell(value):
    if value > 28:
        return 'red'
    else:
        return 'white'

# Create formatted table data
formatted_table_data = [[avg_pip_per_hour.get(hour, 0) for hour in range(24)]]

# Create a table to display average PIP Settings aligned with the x-axis ticks
table_pos = [0.025, -0.25, 0.95, 0.1]  # Adjust the bbox position (left, bottom, width, height)
table = ax.table(cellColours=[[format_table_cell(avg_pip_per_hour.get(hour, 0)) for hour in range(24)]],
                 cellText=formatted_table_data,
                 colLabels=custom_labels,
                 cellLoc='center',
                 loc='bottom', 
                 bbox=table_pos)

# Adjust table properties
table.auto_set_font_size(False)
table.set_fontsize(12)
table.scale(1, 1.5)

# Add a title for the table
table_title = plt.text(0.5, -0.1, 'Average PIP Settings by Hour', horizontalalignment='center', verticalalignment='center',
                       transform=ax.transAxes, fontsize=14)

# Add legend for red text indicating PIP Settings > 28
legend_text = '* Red text: PIP Settings > 28 mbar'
plt.figtext(0.1, -0.01, legend_text, wrap=True, horizontalalignment='center', fontsize=12, color='red')

# Adjust layout
plt.tight_layout()

# Show plot
plt.show()

# %%
## Concatenate all the Mode Category CDGR files.

import os
import pandas as pd

# List to store DataFrames
dfs = []

# Specify the filenames to concatenate
filenames_to_concat = ["/nfs/turbo/med-kayvan-lab/Projects/PARDS/02-Data/02-EVENTS/PvsV_24hrs_Raw/Mode_Cat_CDGR_58.csv", 
                       "/nfs/turbo/med-kayvan-lab/Projects/PARDS/02-Data/02-EVENTS/PvsV_24hrs_Raw/Mode_Cat_CDGR_151.csv"]

# Iterate over specified filenames
for filename in filenames_to_concat:
    # Read CSV file into a DataFrame
    df = pd.read_csv(filename)
    # Add a column indicating the source file
    df['Source_File'] = filename
    # Append DataFrame to the list
    dfs.append(df)

# Concatenate all DataFrames
Mode_Cat_CDGR = pd.concat(dfs, ignore_index=True)

# Display the concatenated DataFrame
print(len(Mode_Cat_CDGR['File Name 2'].unique()))
print(Mode_Cat_CDGR.info())

# # Save the dataframe as a CSV file
# csv_file_path = 'Mode_Cat_CDGR.csv'
# Mode_Cat_CDGR.to_csv(csv_file_path, index=False)
# Out:
# 49
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49 entries, 0 to 48
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   PID            49 non-null     int64
#  1   File Name      49 non-null     object
#  2   File Name 2    49 non-null     object
#  3   Mode Category  49 non-null     object
#  4   Source_File    49 non-null     object
# dtypes: int64(1), object(4)
# memory usage: 2.0+ KB
# None

# %%
## Concatenate all the patient weight CDGR files.

import os
import pandas as pd

# List to store DataFrames
dfs = []

# Specify the filenames to concatenate
filenames_to_concat = ["/nfs/turbo/med-kayvan-lab/Projects/PARDS/02-Data/02-EVENTS/PvsV_24hrs_Raw/58_CDGR_39_24hrs_Weights.csv", 
                       "/nfs/turbo/med-kayvan-lab/Projects/PARDS/02-Data/02-EVENTS/PvsV_24hrs_Raw/151_CDGR_11_24hrs_Weights.csv"]

# Iterate over specified filenames
for filename in filenames_to_concat:
    # Read CSV file into a DataFrame
    df = pd.read_csv(filename)
    # Add a column indicating the source file
    df['Source_File'] = filename
    # Append DataFrame to the list
    dfs.append(df)

# Concatenate all DataFrames
Weights_CDGR = pd.concat(dfs, ignore_index=True)

# Display the concatenated DataFrame
print(len(Weights_CDGR['patient_id'].unique()))
print(Weights_CDGR.info())

# # Save the dataframe as a CSV file
# csv_file_path = 'Weights_CDGR.csv'
# Weights_CDGR.to_csv(csv_file_path, index=False)
# Out:
# 50
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   patient_id     50 non-null     int64
#  1   average_value  50 non-null     float64
#  2   Source_File    50 non-null     object
# dtypes: float64(1), int64(1), object(1)
# memory usage: 1.3+ KB
# None

# %%
# CDGR (all) -- Pressure Control Mode
## Concatenate all the CDGR files.

import os
import pandas as pd

# Directory path
directory_path = "/nfs/turbo/med-kayvan-lab/Projects/PARDS/02-Data/02-EVENTS/PvsV_24hrs_Raw/CDGR/"

# List to store DataFrames
dfs = []

# Iterate over each file in the directory
for filename in os.listdir(directory_path):
    if filename.endswith(".csv"):
        # Read CSV file into a DataFrame
        filepath = os.path.join(directory_path, filename)
        df = pd.read_csv(filepath)
        
        # Extract hour from Time column
        df['Time'] = pd.to_datetime(df['Time'])
        df['Hour'] = df['Time'].dt.hour
        # print(len(df['Hour'].unique()))
        
        # Create Time_Stamp column based on hour
        df['Time_Stamp'] = df['Hour'].apply(lambda hour: f'{hour % 12}{"am" if hour < 12 else "pm"}')
        # print(len(df['Time_Stamp'].unique()))
        
        # Create Time_Stamp_2 column
        df['Time_Stamp_2'] = df['Hour'].apply(lambda hour: f'H{hour + 1}')
        
        # Add a column indicating the source file
        df['Source_File'] = filename
        
        # Append DataFrame to the list
        dfs.append(df)

# Concatenate all DataFrames
result_df = pd.concat(dfs, ignore_index=True)

# Display the number of unique source files
print(len(result_df['Source_File'].unique()))  # Number of unique source files
print(len(result_df['Hour'].unique()))
print(len(result_df['Time_Stamp'].unique()))
print(len(result_df['Time_Stamp_2'].unique()))
print(result_df.info())  # Info about the concatenated DataFrame
# Out:
# 41
# 24
# 24
# 24
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2310836 entries, 0 to 2310835
# Data columns (total 14 columns):
#  #   Column                Dtype
# ---  ------                -----
#  0   Relative Time (sec)   int64
#  1   Time                  datetime64[ns]
#  2   CDGR - PEEP           float64
#  3   CDGR - Set: VT in mL  float64
#  4   CDGR - Set: PIP       float64
#  5   CDGR - Set: PEEP L    float64
#  6   CDGR - eVT            float64
#  7   CDGR - PIP            float64
#  8   CDGR - Pplat          float64
#  9   CDGR - Set: Pinsp     float64
#  10  Hour                  int64
#  11  Time_Stamp            object
#  12  Time_Stamp_2          object
#  13  Source_File           object
# dtypes: datetime64[ns](1), float64(8), int64(2), object(3)
# memory usage: 246.8+ MB
# None

# %%
# CDGR (all) -- Pressure Control Mode

import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# Rename columns
result_df.rename(columns={
    'CDGR - Set: Pinsp': 'PIP_Settings',
    'CDGR - Set: PEEP L': 'PEEP_Settings',
    'CDGR - PIP': 'PIP_Actual',
    'CDGR - PEEP': 'PEEP_Actual',
    'CDGR - eVT': 'Tidal_Volume'
}, inplace=True)

# Print the count of NaN values in 'PIP_Settings' and 'Tidal_Volume'
print(result_df['PIP_Settings'].isna().sum())
print(result_df['Tidal_Volume'].isna().sum())

# Drop rows where 'PIP_Settings' is NaN
result_df.dropna(subset=['PIP_Settings'], inplace=True)

# Drop rows where 'Tidal_Volume' is NaN
result_df.dropna(subset=['Tidal_Volume'], inplace=True)

# Print the count of NaN values in 'PIP_Settings' and 'Tidal_Volume'
print(result_df['PIP_Settings'].isna().sum())
print(result_df['Tidal_Volume'].isna().sum())

# Iterate through each unique filename
for filename in result_df['Source_File'].unique():
    # Step 1: Read the CSV file into a DataFrame
    df1 = Mode_Cat_CDGR
    # Check if "filename" matches "File Name 2" and add PID to title
    matched_row1 = df1[df1["File Name 2"] == str(filename)]
    if not matched_row1.empty:
        pid = matched_row1["PID"].iloc[0]  # Extract PID from filename
        # print("PID:", pid)
        
        # Step 2: Read the weights CSV file into a DataFrame
        df2 = Weights_CDGR
        # Check if "filename" matches "patient_id" and add weight
        matched_row2 = df2[df2["patient_id"] == pid]
        if not matched_row2.empty:
            weight = matched_row2["average_value"].iloc[0]  # Extract weight from dataframe
            # print("Weight:", weight)
            
            # Calculate 'TV(mL/kg)' only if weight is not None
            if weight is not None:
                # Filter rows by filename
                subset_df = result_df[result_df['Source_File'] == filename].copy()  # Make a copy to avoid SettingWithCopyWarning

                # Calculate 'TV(mL/kg)' and assign to a new column using .loc
                subset_df.loc[:, 'TV(mL/kg)'] = subset_df['Tidal_Volume'] / weight

                # Filter rows where 'TV(mL/kg)' is less than 25
                subset_df = subset_df[subset_df['TV(mL/kg)'] < 25]
                # print(len(subset_df['TV(mL/kg)']))
                # print(subset_df['TV(mL/kg)'].isna().sum())
                
                # Update result_df with the calculated values using .loc
                result_df.loc[subset_df.index, 'TV(mL/kg)'] = subset_df['TV(mL/kg)']
                
                # Apply a 2-minute moving average to tidal volume
                df = subset_df.copy()  # Make a copy to avoid SettingWithCopyWarning
                df.set_index('Time', inplace=True)  # Set 'Time' as the index
                df.sort_index(inplace=True)  # Ensure the index is sorted to be monotonic
                df['TV(mL/kg)_ma'] = df['TV(mL/kg)'].rolling('2T').mean()  # Calculate the rolling mean with a 2-minute window
                df.reset_index(drop=True, inplace=True)  # Reset the index to original structure
                # print(len(df['TV(mL/kg)_ma']))
                # print(df['TV(mL/kg)_ma'].isna().sum())
                
                # Update result_df with the calculated values using .loc
                result_df.loc[subset_df.index, 'TV(mL/kg)_ma'] = df['TV(mL/kg)_ma'].values

                # Add PID and weight to the DataFrame using .loc
                result_df.loc[subset_df.index, 'PID'] = pid
                result_df.loc[subset_df.index, 'Weight'] = weight
            else:
                print("Weight is None, cannot calculate 'TV(mL/kg)'.")
        else:
            print("No weight information found for PID:", pid)
    else:
        print("No match found for filename:", filename)
# Out:
# 680
# 77
# 0
# 0

# %%
print(result_df.info())
print(result_df['Source_File'].unique())
print(len(result_df['Source_File'].unique()))
print(result_df['PID'].unique())
print(len(result_df['PID'].unique()))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2310100 entries, 10 to 2310835
# Data columns (total 18 columns):
#  #   Column                Dtype
# ---  ------                -----
#  0   Relative Time (sec)   int64
#  1   Time                  datetime64[ns]
#  2   PEEP_Actual           float64
#  3   CDGR - Set: VT in mL  float64
#  4   CDGR - Set: PIP       float64
#  5   PEEP_Settings         float64
#  6   Tidal_Volume          float64
#  7   PIP_Actual            float64
#  8   CDGR - Pplat          float64
#  9   PIP_Settings          float64
#  10  Hour                  int64
#  11  Time_Stamp            object
#  12  Time_Stamp_2          object
#  13  Source_File           object
#  14  TV(mL/kg)             float64
#  15  TV(mL/kg)_ma          float64
#  16  PID                   float64
#  17  Weight                float64
# dtypes: datetime64[ns](1), float64(12), int64(2), object(3)
# memory usage: 399.4+ MB
# None
# ...

# %%
# Print the count of NaN values in 'TV(mL/kg)' and 'TV(mL/kg)_ma'
print(result_df['TV(mL/kg)'].isna().sum())
print(result_df['TV(mL/kg)_ma'].isna().sum())
# Out:
# 57870
# 57870

# %%
print(result_df[result_df['PID'].isna()])
# Out:
# Empty DataFrame
# Columns: [Relative Time (sec), Time, PEEP_Actual, Volume_Settings, CDGR - Set: PIP, PEEP_Settings, Tidal_Volume, PIP_Actual, CDGR - Pplat, PIP_Settings, Hour, Time_Stamp, Time_Stamp_2, Source_File, TV(mL/kg), TV(mL/kg)_ma, PID, Weight]
# Index: []

# %%
# Drop rows where 'PID' is NaN
result_df.dropna(subset=['PID'], inplace=True)

# %%
print(result_df.info())
print(result_df['Source_File'].unique())
print(len(result_df['Source_File'].unique()))
print(result_df['PID'].unique())
print(len(result_df['PID'].unique()))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2252230 entries, 10 to 2310835
# Data columns (total 18 columns):
#  #   Column                Dtype
# ---  ------                -----
#  0   Relative Time (sec)   int64
#  1   Time                  datetime64[ns]
#  2   PEEP_Actual           float64
#  3   CDGR - Set: VT in mL  float64
#  4   CDGR - Set: PIP       float64
#  5   PEEP_Settings         float64
#  6   Tidal_Volume          float64
#  7   PIP_Actual            float64
#  8   CDGR - Pplat          float64
#  9   PIP_Settings          float64
#  10  Hour                  int64
#  11  Time_Stamp            object
#  12  Time_Stamp_2          object
#  13  Source_File           object
#  14  TV(mL/kg)             float64
#  15  TV(mL/kg)_ma          float64
#  16  PID                   float64
#  17  Weight                float64
# dtypes: datetime64[ns](1), float64(12), int64(2), object(3)
# memory usage: 326.5+ MB
# None
# ...

# %%
# Print the count of NaN values in 'TV(mL/kg)' and 'TV(mL/kg)_ma'
print(result_df['TV(mL/kg)'].isna().sum())
print(result_df['TV(mL/kg)_ma'].isna().sum())
# Out:
# 0
# 0

# %%
print(result_df['TV(mL/kg)'].min())
print(result_df['TV(mL/kg)_ma'].min())
# Out:
# 0.0
# 0.0

# %%
CDGR_PCM_df = result_df
CDGR_PCM_df
# Out:
#          Relative Time (sec)                Time  PEEP_Actual  \
# 10                        53 2023-11-07 06:38:53          7.3
# 11                        55 2023-11-07 06:38:55          7.3
# 12                        57 2023-11-07 06:38:57          8.1
# 13                        59 2023-11-07 06:38:59          7.9
# 14                        60 2023-11-07 06:39:00          7.9
# ...                      ...                 ...          ...
# 2310831                45099 2023-11-22 14:22:39          6.3
# 2310832                45106 2023-11-22 14:22:46          6.3
# 2310833                45112 2023-11-22 14:22:52          6.3
# 2310834                45119 2023-11-22 14:22:59          6.3
# 2310835                45125 2023-11-22 14:23:05          6.3
#
#          CDGR - Set: VT in mL  CDGR - Set: PIP  PEEP_Settings  Tidal_Volume  \
# 10                        NaN              NaN            8.0          73.0
# ...

# %%
len(CDGR_PCM_df['PID'].unique())
# Out:
# 41

# %%
len(CDGR_PCM_df['Source_File'].unique())
# Out:
# 41

# %%
# %store CDGR_PCM_df
# Out:
# Stored 'CDGR_PCM_df' (DataFrame)

# %%
# CDGR (all) -- Volume Control Mode
## Concatenate all the CDGR files.

import os
import pandas as pd

# Directory path
directory_path = "/nfs/turbo/med-kayvan-lab/Projects/PARDS/02-Data/02-EVENTS/PvsV_24hrs_Raw/CDGR_VCM/"

# List to store DataFrames
dfs = []

# Iterate over each file in the directory
for filename in os.listdir(directory_path):
    if filename.endswith(".csv"):
        # Read CSV file into a DataFrame
        filepath = os.path.join(directory_path, filename)
        df = pd.read_csv(filepath)
        
        # Extract hour from Time column
        df['Time'] = pd.to_datetime(df['Time'])
        df['Hour'] = df['Time'].dt.hour
        # print(len(df['Hour'].unique()))
        
        # Create Time_Stamp column based on hour
        df['Time_Stamp'] = df['Hour'].apply(lambda hour: f'{hour % 12}{"am" if hour < 12 else "pm"}')
        # print(len(df['Time_Stamp'].unique()))
        
        # Create Time_Stamp_2 column
        df['Time_Stamp_2'] = df['Hour'].apply(lambda hour: f'H{hour + 1}')
        
        # Add a column indicating the source file
        df['Source_File'] = filename
        
        # Append DataFrame to the list
        dfs.append(df)

# Concatenate all DataFrames
result_df = pd.concat(dfs, ignore_index=True)

# Display the number of unique source files
print(len(result_df['Source_File'].unique()))  # Number of unique source files
print(len(result_df['Hour'].unique()))
print(len(result_df['Time_Stamp'].unique()))
print(len(result_df['Time_Stamp_2'].unique()))
print(result_df.info())  # Info about the concatenated DataFrame
# Out:
# 8
# 24
# 24
# 24
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 430844 entries, 0 to 430843
# Data columns (total 14 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   Relative Time (sec)   430844 non-null  int64
#  1   Time                  430844 non-null  datetime64[ns]
#  2   CDGR - PEEP           430834 non-null  float64
#  3   CDGR - Set: VT in mL  430817 non-null  float64
#  4   CDGR - Set: PIP       0 non-null       float64
#  5   CDGR - Set: PEEP L    430817 non-null  float64
#  6   CDGR - eVT            430819 non-null  float64
#  7   CDGR - PIP            430834 non-null  float64
#  8   CDGR - Pplat          342623 non-null  float64
#  9   CDGR - Set: Pinsp     76677 non-null   float64
#  10  Hour                  430844 non-null  int64
#  11  Time_Stamp            430844 non-null  object
#  12  Time_Stamp_2          430844 non-null  object
#  13  Source_File           430844 non-null  object
# ...

# %%
# CDGR (all) -- Volume Control Mode

import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# Rename columns
result_df.rename(columns={
    'CDGR - Set: Pinsp': 'PIP_Settings',
    'CDGR - Set: PEEP L': 'PEEP_Settings',
    'CDGR - PIP': 'PIP_Actual',
    'CDGR - PEEP': 'PEEP_Actual',
    'CDGR - eVT': 'Tidal_Volume',
    'CDGR - Set: VT in mL': 'Volume_Settings'
}, inplace=True)

# Print the count of NaN values in 'Tidal_Volume' and 'Volume_Settings'
print(result_df['Tidal_Volume'].isna().sum())
print(result_df['Volume_Settings'].isna().sum())

# Drop rows where 'Tidal_Volume' is NaN
result_df.dropna(subset=['Tidal_Volume'], inplace=True)

# Drop rows where 'Volume_Settings' is NaN
result_df.dropna(subset=['Volume_Settings'], inplace=True)

# Print the count of NaN values in 'Tidal_Volume' and 'Volume_Settings'
print(result_df['Tidal_Volume'].isna().sum())
print(result_df['Volume_Settings'].isna().sum())

# Iterate through each unique filename
for filename in result_df['Source_File'].unique():
    # Step 1: Read the CSV file into a DataFrame
    df1 = Mode_Cat_CDGR
    # Check if "filename" matches "File Name 2" and add PID to title
    matched_row1 = df1[df1["File Name 2"] == str(filename)]
    if not matched_row1.empty:
        pid = matched_row1["PID"].iloc[0]  # Extract PID from filename
        # print("PID:", pid)
        
        # Step 2: Read the weights CSV file into a DataFrame
        df2 = Weights_CDGR
        # Check if "filename" matches "patient_id" and add weight
        matched_row2 = df2[df2["patient_id"] == pid]
        if not matched_row2.empty:
            weight = matched_row2["average_value"].iloc[0]  # Extract weight from dataframe
            # print("Weight:", weight)
            
            # Calculate 'TV(mL/kg)' only if weight is not None
            if weight is not None:
                # Filter rows by filename
                subset_df = result_df[result_df['Source_File'] == filename].copy()  # Make a copy to avoid SettingWithCopyWarning

                # Calculate 'TV(mL/kg)' and assign to a new column using .loc
                subset_df.loc[:, 'TV(mL/kg)'] = subset_df['Tidal_Volume'] / weight

                # Filter rows where 'TV(mL/kg)' is less than 25
                subset_df = subset_df[subset_df['TV(mL/kg)'] < 25]
                # print(len(subset_df['TV(mL/kg)']))
                # print(subset_df['TV(mL/kg)'].isna().sum())
                
                # Update result_df with the calculated values using .loc
                result_df.loc[subset_df.index, 'TV(mL/kg)'] = subset_df['TV(mL/kg)']
                
                # Apply a 2-minute moving average to tidal volume
                df = subset_df.copy()  # Make a copy to avoid SettingWithCopyWarning
                df.set_index('Time', inplace=True)  # Set 'Time' as the index
                df.sort_index(inplace=True)  # Ensure the index is sorted to be monotonic
                df['TV(mL/kg)_ma'] = df['TV(mL/kg)'].rolling('2T').mean()  # Calculate the rolling mean with a 2-minute window
                df.reset_index(drop=True, inplace=True)  # Reset the index to original structure
                # print(len(df['TV(mL/kg)_ma']))
                # print(df['TV(mL/kg)_ma'].isna().sum())
                
                # Update result_df with the calculated values using .loc
                result_df.loc[subset_df.index, 'TV(mL/kg)_ma'] = df['TV(mL/kg)_ma'].values

                # Add PID and weight to the DataFrame using .loc
                result_df.loc[subset_df.index, 'PID'] = pid
                result_df.loc[subset_df.index, 'Weight'] = weight
            else:
                print("Weight is None, cannot calculate 'TV(mL/kg)'.")
        else:
            print("No weight information found for PID:", pid)
    else:
        print("No match found for filename:", filename)
# Out:
# 25
# 27
# 0
# 0

# %%
print(result_df.info())
print(result_df['Source_File'].unique())
print(len(result_df['Source_File'].unique()))
print(result_df['PID'].unique())
print(len(result_df['PID'].unique()))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 430795 entries, 7 to 430843
# Data columns (total 18 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   Relative Time (sec)  430795 non-null  int64
#  1   Time                 430795 non-null  datetime64[ns]
#  2   PEEP_Actual          430794 non-null  float64
#  3   Volume_Settings      430795 non-null  float64
#  4   CDGR - Set: PIP      0 non-null       float64
#  5   PEEP_Settings        430795 non-null  float64
#  6   Tidal_Volume         430795 non-null  float64
#  7   PIP_Actual           430794 non-null  float64
#  8   CDGR - Pplat         342623 non-null  float64
#  9   PIP_Settings         76677 non-null   float64
#  10  Hour                 430795 non-null  int64
#  11  Time_Stamp           430795 non-null  object
#  12  Time_Stamp_2         430795 non-null  object
#  13  Source_File          430795 non-null  object
# ...

# %%
# Print the count of NaN values in 'TV(mL/kg)' and 'TV(mL/kg)_ma'
print(result_df['TV(mL/kg)'].isna().sum())
print(result_df['TV(mL/kg)_ma'].isna().sum())
# Out:
# 2306
# 2306

# %%
print(result_df[result_df['PID'] == "nan"])
# Out:
# Empty DataFrame
# Columns: [Relative Time (sec), Time, PEEP_Actual, Volume_Settings, CDGR - Set: PIP, PEEP_Settings, Tidal_Volume, PIP_Actual, CDGR - Pplat, PIP_Settings, Hour, Time_Stamp, Time_Stamp_2, Source_File, TV(mL/kg), TV(mL/kg)_ma, PID, Weight]
# Index: []

# %%
# Drop rows where 'PID' is NaN
result_df.dropna(subset=['PID'], inplace=True)

# %%
# Print the count of NaN values in 'TV(mL/kg)' and 'TV(mL/kg)_ma'
print(result_df['TV(mL/kg)'].isna().sum())
print(result_df['TV(mL/kg)_ma'].isna().sum())
# Out:
# 0
# 0

# %%
print(result_df['TV(mL/kg)'].min())
print(result_df['TV(mL/kg)_ma'].min())
# Out:
# 0.0
# 0.0

# %%
CDGR_VCM_df = result_df
CDGR_VCM_df
# Out:
#         Relative Time (sec)                Time  PEEP_Actual  Volume_Settings  \
# 7                        55 2023-09-18 13:53:55          5.9             90.0
# 8                        56 2023-09-18 13:53:56          5.9             90.0
# 9                        57 2023-09-18 13:53:57          5.9             90.0
# 10                       58 2023-09-18 13:53:58          5.9             90.0
# 11                       59 2023-09-18 13:53:59          5.8             90.0
# ...                     ...                 ...          ...              ...
# 430839                86393 2023-10-12 22:50:53          8.0            200.0
# 430840                86394 2023-10-12 22:50:54          8.0            200.0
# 430841                86395 2023-10-12 22:50:55          8.0            200.0
# 430842                86397 2023-10-12 22:50:57          8.0            200.0
# 430843                86399 2023-10-12 22:50:59          7.8            200.0
#
# ...

# %%
len(CDGR_VCM_df['PID'].unique())
# Out:
# 8

# %%
len(CDGR_VCM_df['Source_File'].unique())
# Out:
# 8

# %%
temp_df = CDGR_VCM_df[CDGR_VCM_df['PIP_Settings'].notna()]

# %%
temp_df.groupby('PID')['PIP_Settings'].unique()
# Out:
# PID
# 65281.0      [12.0]
# 1025114.0    [18.0]
# Name: PIP_Settings, dtype: object

# %%
# %store CDGR_VCM_df
# Out:
# Stored 'CDGR_VCM_df' (DataFrame)

# %%
# ### Abnormal values detection for result_df['TV(mL/kg)']

# print(result_df.info())
# print(len(result_df['PID'].unique()))
# print(len(result_df['Weight'].unique()))

# # Group by 'Weight' and filter groups with more than one unique PID
# duplicate_weights = result_df.groupby('Weight')['PID'].nunique()
# duplicate_weights = duplicate_weights[duplicate_weights > 1]

# # If there are duplicate weights, find the corresponding PIDs
# if not duplicate_weights.empty:
#     print("Weights with multiple PIDs:")
#     for weight in duplicate_weights.index:
#         pids = result_df[result_df['Weight'] == weight]['PID'].unique()
#         print(f"Weight: {weight}, PIDs: {list(pids.astype(int))}")
# else:
#     print("No duplicate weights found.")

# # Filter rows where 'TV(mL/kg)' is greater than 25
# filtered_df = result_df[result_df['TV(mL/kg)'] > 25]

# # Display specific columns for the filtered rows
# relevant_columns = ['PID', 'Time', 'PIP_Settings', 'Tidal_Volume', 'TV(mL/kg)', 'Weight']
# filtered_data = filtered_df[relevant_columns]
# filtered_data['PID'] = filtered_data['PID'].astype(int)

# # Print or display the filtered data
# print(filtered_data.info())
# print(filtered_data['PID'].astype(int).unique())

# # Define the file path where you want to save the CSV file
# csv_file_path = 'CDGR_TV_GreaterThan_25.csv'

# # Save the filtered data to a CSV file
# filtered_data.to_csv(csv_file_path, index=False)

# %%
# Violinplot for all CDGR by PIP Settings

# Set the size of the plot
plt.figure(figsize=(20, 10))

# Create violin plot
sns.violinplot(data=result_df, x='PIP_Settings', y='TV(mL/kg)_ma', hue='PIP_Settings', palette='muted', legend=False)
plt.xlabel('PIP Settings (mbar)', fontsize=16)
plt.ylabel('Tidal Volume (mL/kg)', fontsize=16)
plt.title('CDGR Ventilator: Tidal Volume Distribution across PIP Settings', fontsize=20)

# Add thresholds for Volume in violin plot
plt.axhline(y=6, color='r', linestyle='--', linewidth=1, label='Tidal Volume = 6 mL/kg')
plt.axhline(y=8, color='b', linestyle='--', linewidth=1, label='Tidal Volume = 8 mL/kg')

# Find the index corresponding to PIP Setting of 28.0
# Get unique PIP_Settings values and drop NaN
x_index = result_df['PIP_Settings'].dropna().unique()
# Sort the unique values in ascending order
x_index.sort()
# Find the index corresponding to PIP Setting of 28.0
pip_28_index = np.where(x_index == 28.0)[0][0]
# Add vertical line at x=28.0
plt.axvline(x=pip_28_index, color='g', linestyle='--', linewidth=2, label='PIP Setting = 28 mbar')

plt.xticks(fontsize=12)
plt.yticks(fontsize=12)

# plt.legend()
plt.legend(title='Legend', bbox_to_anchor=(1, 1), loc='upper left', fontsize=16)
plt.show()

# %%
# PIP Settings v.s Tidal Volume in time series for the Pressure Control Mode cohort
## CDGR (all) -- Violinplot(Boxplot) + Table

import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = result_df
# print(df.info())

# Calculate average, minimum, and maximum PIP Settings per hour
pip_stats_per_hour = df.groupby('Time_Stamp_2')['PIP_Settings'].agg(['mean', 'min', 'max']).round().astype(int)
# Rename the columns for clarity
pip_stats_per_hour.rename(columns={'mean': 'Average_PIP_Settings', 'min': 'Min_PIP_Settings', 'max': 'Max_PIP_Settings'}, inplace=True)
# print(pip_stats_per_hour)

# # Calculate average tidal volume at 8 am
# eight_am_data = df[(df['Time'].dt.time >= pd.to_datetime('08:00:00').time()) & 
#                    (df['Time'].dt.time <= pd.to_datetime('08:01:00').time())]
# eight_am_avg = eight_am_data['TV(mL/kg)'].mean()

# Plotting
fig, ax = plt.subplots(figsize=(20, 10))

# Violin plot for Tidal Volume by Hour
sns.violinplot(ax=ax, x='Time_Stamp_2', y='TV(mL/kg)_ma', data=df, inner='box', hue='Time_Stamp_2', palette='muted', legend=False)

# # Box plot for Tidal Volume by Hour
# sns.boxplot(ax=ax, x='Time_Stamp_2', y='TV(mL/kg)_ma', data=df, hue='Time_Stamp_2', palette='muted', showfliers=False)

# Add thresholds for Volume in violin plot
ax.axhline(y=6, color='g', linestyle='--', linewidth=1, label='Tidal Volume = 6 mL/kg')
ax.axhline(y=8, color='g', linestyle='--', linewidth=1, label='Tidal Volume = 8 mL/kg')

# Add light green background between the two lines
ax.axhspan(ymin=6, ymax=8, color='lightgreen', alpha=0.3)

# Add legend
# ax.legend()
ax.legend(title='Legend', bbox_to_anchor=(1, 1), loc='upper left', fontsize=16)

# Add a title for the violin plot
ax.set_title('Tidal Volume by Hour', pad=18, fontsize=20)  # Increase pad to adjust title position

# Title and labels for the violin plot
ax.set_ylabel('Tidal Volume (mL/kg)', fontsize=16)
ax.set_xlabel('Hour', fontsize=16)

# Create custom labels for the x-axis
# custom_labels = ['{}am'.format(hour) if hour < 12 else '{}pm'.format(hour - 12) for hour in range(24)]
# custom_labels[0] = '12am'
# custom_labels[12] = '12pm'
custom_labels = df['Time_Stamp_2'].unique()
custom_labels = sorted(custom_labels, key=lambda x: int(x[1:]))

# Set custom x-axis labels (bottom x-axis)
ax.set_xticks(range(24))
ax.set_xticklabels(custom_labels)
ax.tick_params(axis='x', labelsize=16)
ax.tick_params(axis='y', labelsize=16)

# # Hide x-axis ticks
# ax.xaxis.set_ticks([])

# Custom function to format table cells
def format_table_cell(value):
    if value > 28:
        return 'red'
    else:
        return 'white'

# Create formatted table data
formatted_table_data = [
    [pip_stats_per_hour['Min_PIP_Settings'].get(hour, 0) for hour in range(24)],
    [pip_stats_per_hour['Average_PIP_Settings'].get(hour, 0) for hour in range(24)],
    [pip_stats_per_hour['Max_PIP_Settings'].get(hour, 0) for hour in range(24)]
]

# Create cell colors based on the value
cell_colors = []
for row in formatted_table_data:
    color_row = [format_table_cell(value) for value in row]
    cell_colors.append(color_row)

# Define custom labels for the rows and columns
row_labels = ['Min', 'Average', 'Max']
# col_labels = [f'{hour}am' if hour < 12 else f'{hour - 12}pm' for hour in range(24)]
# col_labels[0] = '12am'
# col_labels[12] = '12pm'
col_labels = df['Time_Stamp_2'].unique()
col_labels = sorted(col_labels, key=lambda x: int(x[1:]))

# Create a table to display min, average, and max PIP Settings
table_pos = [0.025, -0.35, 0.95, 0.2]  # Adjust the bbox position (left, bottom, width, height)
table = ax.table(cellText=formatted_table_data,
                 rowLabels=row_labels,
                 colLabels=col_labels,
                 cellLoc='center',
                 cellColours=cell_colors,
                 loc='bottom', 
                 bbox=table_pos)

# Adjust table properties
table.auto_set_font_size(False)
table.set_fontsize(16)
table.scale(1, 1.5)

# Add a title for the table
table_title = plt.text(0.5, -0.12, 'Min, Average, and Max PIP Settings by Hour', horizontalalignment='center', verticalalignment='center',
                       transform=ax.transAxes, fontsize=20)

# Add legend for red text indicating PIP Settings > 28
legend_text = '* Red text: PIP Settings > 28 mbar'
plt.figtext(0.1, -0.01, legend_text, wrap=True, horizontalalignment='center', fontsize=12, color='red')

# Adjust layout
plt.tight_layout()

# Show plot
plt.show()

# %%
# PIP Settings v.s Tidal Volume in time series for the Pressure Control Mode cohort
## CDGR (all) -- Violinplot(Boxplot) + Boxplot

import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming df is your existing DataFrame
# Ensure df has 'TV(mL/kg)', 'PIP_Settings', and 'Hour' columns
df = result_df

# Create subplots
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(20, 10), sharex=True, gridspec_kw={'height_ratios': [2, 1]})

# Violin plot for Tidal Volume by Hour
sns.violinplot(ax=ax1, x='Time_Stamp_2', y='TV(mL/kg)_ma', data=df, inner='box', hue='Time_Stamp_2', palette='muted', legend=False)

# # Box plot for Tidal Volume by Hour
# sns.boxplot(ax=ax1, x='Time_Stamp_2', y='TV(mL/kg)', data=df, hue='Time_Stamp_2', palette='muted', showfliers=False)

# Add thresholds for Volume in violin plot
ax1.axhline(y=6, color='g', linestyle='--', linewidth=1, label='Tidal Volume = 6 mL/kg')
ax1.axhline(y=8, color='g', linestyle='--', linewidth=1, label='Tidal Volume = 8 mL/kg')

# Add light green background between the two lines
ax1.axhspan(ymin=6, ymax=8, color='lightgreen', alpha=0.3)

# # Add legend
# ax1.legend()

# Adding legend for the markers
ax1.legend(title='Legend', bbox_to_anchor=(1, 1), loc='upper left', fontsize=16)

# Add a title for the violin plot
ax1.set_title('Tidal Volume by Hour', pad=18, fontsize=20)  # Increase pad to adjust title position

# Title and labels for the violin plot
ax1.set_ylabel('Tidal Volume (mL/kg)', fontsize=16)

# Boxplot for PIP Settings by Hour
sns.boxplot(ax=ax2, x='Time_Stamp_2', y='PIP_Settings', data=df, hue='Time_Stamp_2', palette='muted', legend=False)

# Add threshold line for PIP Settings = 28
ax2.axhline(y=28, color='r', linestyle='--', linewidth=1, label='PIP Settings = 28 mbar')

# # Add legend
# ax2.legend()

# Adding legend for the markers
ax2.legend(title='Legend', bbox_to_anchor=(1, 1), loc='upper left', fontsize=16)

# Add a title for the boxplot
ax2.set_title('PIP Settings by Hour', pad=18, fontsize=20)  # Increase pad to adjust title position

# Title and labels for the boxplot
ax2.set_ylabel('PIP Settings (mbar)', fontsize=16)
ax2.set_xlabel('Hour', fontsize=16)

# Create custom labels for the x-axis
# custom_labels = ['{}am'.format(hour) if hour < 12 else '{}pm'.format(hour - 12) for hour in range(24)]
# custom_labels[0] = '12am'
# custom_labels[12] = '12pm'
custom_labels = df['Time_Stamp_2'].unique()
custom_labels = sorted(custom_labels, key=lambda x: int(x[1:]))

# Set custom x-axis labels (bottom x-axis)
ax2.set_xticks(range(24))
ax2.set_xticklabels(custom_labels)
ax2.tick_params(axis='x', labelsize=16)
ax2.tick_params(axis='y', labelsize=16)

# Adjust layout
plt.tight_layout()

# Show plot
plt.show()

# %% [markdown]
# - For AVEAA: PIP settings = AVEA - Set: PEEP + AVEA - Set: Pinsp

# %%
# AVEAA (indiviual sample)

import os
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Directory path
## 24hrs version:
directory_path = "/nfs/turbo/med-kayvan-lab/Projects/PARDS/02-Data/02-EVENTS/PvsV_24hrs_Raw/AVEAA/"
## Raw version:
# directory_path = "/nfs/turbo/med-kayvan-lab/Projects/PARDS/02-Data/02-EVENTS/PvsV_1hr_Raw/AVEAA/"
# ## Cleaned version:
# directory_path = "/nfs/turbo/med-kayvan-lab/Projects/PARDS/02-Data/02-EVENTS/PvsV_1hr_Cleaned/AVEAA/"

# filename = "a_58_AVEAA_4_24hrs (4).csv"
filename = "b_151_AVEAA_4_24hrs (3).csv"

filepath = os.path.join(directory_path, filename)

# Read the CSV file into a pandas DataFrame
df = pd.read_csv(filepath)

df['Time'] = pd.to_datetime(df['Time'], format='%Y-%m-%d %H:%M:%S.%f')
df['PIP_Settings'] = df['AVEA - Set: PEEP'] + df['AVEA - Set: Pinsp']

# Rename columns
df.rename(columns={
    'PIP_Settings': 'PIP_Settings',
    'AVEA - Set: PEEP': 'PEEP_Settings',
    'AVEA - PIP': 'PIP_Actual',
    'AVEA - PEEP': 'PEEP_Actual',
    'AVEA - eVT': 'Tidal_Volume'
}, inplace=True)

## Add PID to the title
# Step 1: Read the CSV file into a DataFrame
# df1 = pd.read_csv("Mode_Cat_AVEAA_58.csv")
df1 = pd.read_csv("Mode_Cat_AVEAA_151.csv")

# Step 2: Check if "filename" matches "File Name 2" and add PID to title
matched_row1 = df1[df1["File Name 2"] == filename]

if not matched_row1.empty:
    pid = matched_row1["PID"].iloc[0]  # Extract PID from filename
    print(pid)
    title = f'AVEAA Ventilator (PID: {pid})'  # Create the title with PID
else:
    title = "AVEAA Ventilator"
    
## Add patient weight according to the PID
# Step 1: Read the CSV file into a DataFrame
# df2 = pd.read_csv("58_AVEAA_4_24hrs_Weights.csv")
df2 = pd.read_csv("151_AVEAA_4_24hrs_Weights.csv")

# Step 2: Check if "filename" matches "File Name 2" and add PID to title
matched_row2 = df2[df2["patient_id"] == pid]

if not matched_row2.empty:
    weight = matched_row2["average_value"].iloc[0]  # Extract PID from filename
    print(weight)
else:
    weight = None

df['TV(mL/kg)'] = df['Tidal_Volume'] / weight
print(df['TV(mL/kg)'])

# Calculate average tidal volume at 8 am
eight_am_data = df[(df['Time'].dt.time >= pd.to_datetime('08:00:00').time()) & 
                   (df['Time'].dt.time <= pd.to_datetime('08:01:00').time())]

# Calculate average tidal volume at 8 am
eight_am_avg = eight_am_data['TV(mL/kg)'].mean()

# Create subplots with shared y-axis
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14, 8), sharey=True)

# Add a title for the entire figure including PID
fig.suptitle(title, fontsize=16)

# Violin plot
sns.violinplot(data=df, x='PIP_Settings', y='TV(mL/kg)', hue='PIP_Settings', palette='muted', ax=ax1, legend=False)
ax1.set_xlabel('PIP Settings (cmH2O)')
ax1.set_ylabel('Tidal Volume (mL/kg)')
ax1.set_title('Tidal Volume Distribution across PIP Settings')

# Add thresholds for Volume in violin plot
ax1.axhline(y=6, color='r', linestyle='--', linewidth=1, label='Tidal Volume = 6 mL/kg')
ax1.axhline(y=8, color='b', linestyle='--', linewidth=1, label='Tidal Volume = 8 mL/kg')
ax1.legend()

# Get unique PIP_Settings values for the violin plot, remove NaN, and sort from smallest to largest
unique_pip_settings = df['PIP_Settings'].dropna().unique()
unique_pip_settings.sort()
# Get the first row's "PIP_Settings" value from eight_am_data
first_row_pip_settings = eight_am_data.iloc[0]['PIP_Settings']
# Get the index of the first_row_pip_settings value in the unique_pip_settings list
index_of_first_row_pip_settings = list(unique_pip_settings).index(first_row_pip_settings)
# Plot average tidal volume at 8 am as red dot
ax1.scatter([index_of_first_row_pip_settings], [eight_am_avg], color='red', s=50, label=f'Average Tidal Volume at 8 am', zorder=10)
ax1.annotate(f'{eight_am_avg:.2f} mL/kg', xy=(index_of_first_row_pip_settings, eight_am_avg), xytext=(index_of_first_row_pip_settings+0.2, eight_am_avg+1),
             arrowprops=dict(shrink=0.1, width=1.5, headwidth=8, color='red'), color='red', fontsize=12)
ax1.legend()

# Box plot for volume at 8 am
sns.boxplot(data=eight_am_data, x='PIP_Settings', y='TV(mL/kg)', color='cyan', width=0.3, fliersize=0, ax=ax2)
ax2.set_xlabel('PIP Settings (cmH2O)')
ax2.set_ylabel('Tidal Volume (mL/kg)')
ax2.set_title('Tidal Volume at 8 am')

# Add thresholds for Volume in box plot
ax2.axhline(y=6, color='r', linestyle='--', linewidth=1, label='Tidal Volume = 6 mL/kg')
ax2.axhline(y=8, color='b', linestyle='--', linewidth=1, label='Tidal Volume = 8 mL/kg')
ax2.legend()

plt.show()

# %%
# PIP Settings v.s Tidal Volume in time series for the Pressure Control Mode cohort
## AVEAA (indiviual sample)

import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming df is your existing DataFrame
# Ensure df has 'TV(mL/kg)', 'PIP_Settings', and 'Time' columns

# Extract hour from the Time column
df['Hour'] = df['Time'].dt.hour

# Calculate average PIP Settings per hour
avg_pip_per_hour = df.groupby('Hour')['PIP_Settings'].mean().round().astype(int)  # Round and convert to int

# Calculate average tidal volume at 8 am
eight_am_data = df[(df['Time'].dt.time >= pd.to_datetime('08:00:00').time()) & 
                   (df['Time'].dt.time <= pd.to_datetime('08:01:00').time())]
eight_am_avg = eight_am_data['TV(mL/kg)'].mean()

# Plotting
fig, ax = plt.subplots(figsize=(16, 10))

# Add a title for the entire figure including PID
fig.suptitle(title, fontsize=16)

# Violin plot for Tidal Volume by Hour
sns.violinplot(ax=ax, x='Hour', y='TV(mL/kg)', data=df, inner=None, hue='Hour', palette='muted', legend=False)

# Add thresholds for Volume in violin plot
ax.axhline(y=6, color='g', linestyle='--', linewidth=1, label='Tidal Volume = 6 mL/kg')
ax.axhline(y=8, color='g', linestyle='--', linewidth=1, label='Tidal Volume = 8 mL/kg')

# Add light green background between the two lines
ax.axhspan(ymin=6, ymax=8, color='lightgreen', alpha=0.3)

# # Adding legend for the markers
# ax.legend(title='Legend', bbox_to_anchor=(1, 1), loc='upper left')

# Get unique hours for the x-axis ticks
hours = sorted(df['Hour'].unique())

# Plot average tidal volume at 8 am as red dot
ax.scatter([hours.index(8)], [eight_am_avg], color='red', s=50, label=f'Average Tidal Volume at 8 am')
ax.annotate(f'{eight_am_avg:.2f} mL/kg', xy=(hours.index(8), eight_am_avg), xytext=(hours.index(8) + 0.2, eight_am_avg + 1),
             arrowprops=dict(shrink=0.1, width=1.5, headwidth=8, color='red'), color='red', fontsize=12)

# Add legend
ax.legend()

# Add a title for the violin plot
ax.set_title('Tidal Volume by Hour', fontsize=16, pad=18)  # Increase pad to adjust title position

# Title and labels for the violin plot
ax.set_ylabel('Tidal Volume (mL/kg)')
ax.set_xlabel('Hour')
# # Adjust the position of the x-axis label
# ax.xaxis.set_label_coords(0.5, 0.05)

# Create custom labels for the x-axis
custom_labels = ['{}am'.format(hour) if hour < 12 else '{}pm'.format(hour - 12) for hour in range(24)]

# Set custom x-axis labels (bottom x-axis)
ax.set_xticks(range(24))
ax.set_xticklabels(custom_labels)

# # Hide x-axis ticks
# ax.xaxis.set_ticks([])

# Custom function to format table cells
def format_table_cell(value):
    if value > 28:
        return 'red'
    else:
        return 'white'

# Create formatted table data
formatted_table_data = [[avg_pip_per_hour.get(hour, 0) for hour in range(24)]]

# Create a table to display average PIP Settings aligned with the x-axis ticks
table_pos = [0.025, -0.25, 0.95, 0.1]  # Adjust the bbox position (left, bottom, width, height)
table = ax.table(cellColours=[[format_table_cell(avg_pip_per_hour.get(hour, 0)) for hour in range(24)]],
                 cellText=formatted_table_data,
                 colLabels=custom_labels,
                 cellLoc='center',
                 loc='bottom', 
                 bbox=table_pos)

# Adjust table properties
table.auto_set_font_size(False)
table.set_fontsize(12)
table.scale(1, 1.5)

# Add a title for the table
table_title = plt.text(0.5, -0.1, 'Average PIP Settings by Hour', horizontalalignment='center', verticalalignment='center',
                       transform=ax.transAxes, fontsize=14)

# Add legend for red text indicating PIP Settings > 28
legend_text = '* Red text: PIP Settings > 28 mbar'
plt.figtext(0.1, -0.01, legend_text, wrap=True, horizontalalignment='center', fontsize=12, color='red')

# Adjust layout
plt.tight_layout()

# Show plot
plt.show()

# %%
## Concatenate all the Mode Category AVEAA files.

import os
import pandas as pd

# List to store DataFrames
dfs = []

# Specify the filenames to concatenate
filenames_to_concat = ["/nfs/turbo/med-kayvan-lab/Projects/PARDS/02-Data/02-EVENTS/PvsV_24hrs_Raw/Mode_Cat_AVEAA_58.csv", 
                       "/nfs/turbo/med-kayvan-lab/Projects/PARDS/02-Data/02-EVENTS/PvsV_24hrs_Raw/Mode_Cat_AVEAA_151.csv"]

# Iterate over specified filenames
for filename in filenames_to_concat:
    # Read CSV file into a DataFrame
    df = pd.read_csv(filename)
    # Add a column indicating the source file
    df['Source_File'] = filename
    # Append DataFrame to the list
    dfs.append(df)

# Concatenate all DataFrames
Mode_Cat_AVEAA = pd.concat(dfs, ignore_index=True)

# Display the concatenated DataFrame
print(len(Mode_Cat_AVEAA['File Name 2'].unique()))

# # Save the dataframe as a CSV file
# csv_file_path = 'Mode_Cat_AVEAA.csv'
# Mode_Cat_AVEAA.to_csv(csv_file_path, index=False)
# Out:
# 8

# %%
## Concatenate all the patient weight AVEAA files.

import os
import pandas as pd

# List to store DataFrames
dfs = []

# Specify the filenames to concatenate
filenames_to_concat = ["/nfs/turbo/med-kayvan-lab/Projects/PARDS/02-Data/02-EVENTS/PvsV_24hrs_Raw/58_AVEAA_4_24hrs_Weights.csv", 
                       "/nfs/turbo/med-kayvan-lab/Projects/PARDS/02-Data/02-EVENTS/PvsV_24hrs_Raw/151_AVEAA_4_24hrs_Weights.csv"]

# Iterate over specified filenames
for filename in filenames_to_concat:
    # Read CSV file into a DataFrame
    df = pd.read_csv(filename)
    # Add a column indicating the source file
    df['Source_File'] = filename
    # Append DataFrame to the list
    dfs.append(df)

# Concatenate all DataFrames
Weights_AVEAA = pd.concat(dfs, ignore_index=True)

# Display the concatenated DataFrame
print(len(Weights_AVEAA['patient_id'].unique()))

# # Save the dataframe as a CSV file
# csv_file_path = 'Weights_AVEAA.csv'
# Weights_AVEAA.to_csv(csv_file_path, index=False)
# Out:
# 8

# %%
# AVEAA (all)
## Concatenate all the AVEAA files.

import os
import pandas as pd

# Directory path
directory_path = "/nfs/turbo/med-kayvan-lab/Projects/PARDS/02-Data/02-EVENTS/PvsV_24hrs_Raw/AVEAA/"

# List to store DataFrames
dfs = []

# Iterate over each file in the directory
for filename in os.listdir(directory_path):
    if filename.endswith(".csv"):
        # Read CSV file into a DataFrame
        filepath = os.path.join(directory_path, filename)
        df = pd.read_csv(filepath)
        
        # Separate df['Time'] into 24 hours
        df['Hour'] = pd.to_datetime(df['Time']).dt.hour
        # print(len(df['Hour'].unique()))
        
        # Create Time_Stamp column based on hour
        df['Time_Stamp'] = df['Hour'].apply(lambda hour: f'{hour % 12}{"am" if hour < 12 else "pm"}')
        # print(len(df['Time_Stamp'].unique()))
        
        # Create Time_Stamp_2 column
        df['Time_Stamp_2'] = df['Hour'].apply(lambda hour: f'H{hour + 1}')
        
        # Add a column indicating the source file
        df['Source_File'] = filename
        
        # Append DataFrame to the list
        dfs.append(df)

# Concatenate all DataFrames
result_df = pd.concat(dfs, ignore_index=True)

# Display the concatenated DataFrame
print(len(result_df['Source_File'].unique()))  # Number of unique source files
print(len(result_df['Hour'].unique()))
print(len(result_df['Time_Stamp'].unique()))
print(len(result_df['Time_Stamp_2'].unique()))
print(result_df.info())  # Info about the concatenated DataFrame
# Out:
# 8
# 24
# 24
# 24
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 211843 entries, 0 to 211842
# Data columns (total 13 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   Relative Time (sec)  211843 non-null  int64
#  1   Time                 211843 non-null  object
#  2   AVEA - PEEP          211839 non-null  float64
#  3   AVEA - Set: iVT      211835 non-null  float64
#  4   AVEA - eVT           211838 non-null  float64
#  5   AVEA - PIP           211839 non-null  float64
#  6   AVEA - Set: PEEP     211835 non-null  float64
#  7   AVEA - Pplat         0 non-null       float64
#  8   AVEA - Set: Pinsp    211835 non-null  float64
#  9   Hour                 211843 non-null  int64
#  10  Time_Stamp           211843 non-null  object
#  11  Time_Stamp_2         211843 non-null  object
#  12  Source_File          211843 non-null  object
# dtypes: float64(7), int64(2), object(4)
# memory usage: 21.0+ MB
# None

# %%
# AVEAA (all)

import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

result_df['PIP_Settings'] = result_df['AVEA - Set: PEEP'] + result_df['AVEA - Set: Pinsp']

# Rename columns
result_df.rename(columns={
    'PIP_Settings': 'PIP_Settings',
    'AVEA - Set: PEEP': 'PEEP_Settings',
    'AVEA - PIP': 'PIP_Actual',
    'AVEA - PEEP': 'PEEP_Actual',
    'AVEA - eVT': 'Tidal_Volume'
}, inplace=True)

# Print the count of NaN values in 'PIP_Settings' and 'Tidal_Volume'
print(result_df['PIP_Settings'].isna().sum())
print(result_df['Tidal_Volume'].isna().sum())

# Drop rows where 'PIP_Settings' is NaN
result_df.dropna(subset=['PIP_Settings'], inplace=True)

# Drop rows where 'Tidal_Volume' is NaN
result_df.dropna(subset=['Tidal_Volume'], inplace=True)

# Print the count of NaN values in 'PIP_Settings' and 'Tidal_Volume'
print(result_df['PIP_Settings'].isna().sum())
print(result_df['Tidal_Volume'].isna().sum())

# Iterate through each unique filename
for filename in result_df['Source_File'].unique():
    # Step 1: Read the CSV file into a DataFrame
    df1 = Mode_Cat_AVEAA
    # Check if "filename" matches "File Name 2" and add PID to title
    matched_row1 = df1[df1["File Name 2"] == str(filename)]
    if not matched_row1.empty:
        pid = matched_row1["PID"].iloc[0]  # Extract PID from filename
        # print("PID:", pid)
        
        # Step 2: Read the weights CSV file into a DataFrame
        df2 = Weights_AVEAA
        # Check if "filename" matches "patient_id" and add weight
        matched_row2 = df2[df2["patient_id"] == pid]
        if not matched_row2.empty:
            weight = matched_row2["average_value"].iloc[0]  # Extract weight from dataframe
            # print("Weight:", weight)
            
            # Calculate 'TV(mL/kg)' only if weight is not None
            if weight is not None:
                # Filter rows by filename
                subset_df = result_df[result_df['Source_File'] == filename].copy()  # Make a copy to avoid SettingWithCopyWarning

                # Calculate 'TV(mL/kg)' and assign to a new column using .loc
                subset_df.loc[:, 'TV(mL/kg)'] = subset_df['Tidal_Volume'] / weight

                # Filter rows where 'TV(mL/kg)' is less than 25
                subset_df = subset_df[subset_df['TV(mL/kg)'] < 25]
                # print(len(subset_df['TV(mL/kg)']))
                # print(subset_df['TV(mL/kg)'].isna().sum())
                
                # Update result_df with the calculated values using .loc
                result_df.loc[subset_df.index, 'TV(mL/kg)'] = subset_df['TV(mL/kg)']
                
                # Apply a 2-minute moving average to tidal volume
                df = subset_df.copy()  # Make a copy to avoid SettingWithCopyWarning
                df['Time'] = pd.to_datetime(df['Time'])  # Ensure 'Time' column is datetime type
                df.set_index('Time', inplace=True)  # Set 'Time' as the index
                df.sort_index(inplace=True)  # Ensure the index is sorted to be monotonic
                df['TV(mL/kg)_ma'] = df['TV(mL/kg)'].rolling('2T').mean()  # Calculate the rolling mean with a 2-minute window
                df.reset_index(drop=True, inplace=True)  # Reset the index to original structure
                # print(len(df['TV(mL/kg)_ma']))
                # print(df['TV(mL/kg)_ma'].isna().sum())
                
                # Update result_df with the calculated values using .loc
                result_df.loc[subset_df.index, 'TV(mL/kg)_ma'] = df['TV(mL/kg)_ma'].values

                # Add PID and weight to the DataFrame using .loc
                result_df.loc[subset_df.index, 'PID'] = pid
                result_df.loc[subset_df.index, 'Weight'] = weight
            else:
                print("Weight is None, cannot calculate 'TV(mL/kg)'.")
        else:
            print("No weight information found for PID:", pid)
    else:
        print("No match found for filename:", filename)
# Out:
# 8
# 5
# 0
# 0

# %%
print(result_df.info())
print(result_df['Source_File'].unique())
print(len(result_df['Source_File'].unique()))
print(result_df['PID'].unique())
print(len(result_df['PID'].unique()))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 211830 entries, 8 to 211842
# Data columns (total 18 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   Relative Time (sec)  211830 non-null  int64
#  1   Time                 211830 non-null  object
#  2   PEEP_Actual          211830 non-null  float64
#  3   AVEA - Set: iVT      211830 non-null  float64
#  4   Tidal_Volume         211830 non-null  float64
#  5   PIP_Actual           211830 non-null  float64
#  6   PEEP_Settings        211830 non-null  float64
#  7   AVEA - Pplat         0 non-null       float64
#  8   AVEA - Set: Pinsp    211830 non-null  float64
#  9   Hour                 211830 non-null  int64
#  10  Time_Stamp           211830 non-null  object
#  11  Time_Stamp_2         211830 non-null  object
#  12  Source_File          211830 non-null  object
#  13  PIP_Settings         211830 non-null  float64
# ...

# %%
# Print the count of NaN values in 'TV(mL/kg)' and 'TV(mL/kg)_ma'
print(result_df['TV(mL/kg)'].isna().sum())
print(result_df['TV(mL/kg)_ma'].isna().sum())
# Out:
# 2332
# 2332

# %%
print(result_df[result_df['PID'] == "nan"])
# Out:
# Empty DataFrame
# Columns: [Relative Time (sec), Time, PEEP_Actual, AVEA - Set: iVT, Tidal_Volume, PIP_Actual, PEEP_Settings, AVEA - Pplat, AVEA - Set: Pinsp, Hour, Time_Stamp, Time_Stamp_2, Source_File, PIP_Settings, TV(mL/kg), TV(mL/kg)_ma, PID, Weight]
# Index: []

# %%
# Drop rows where 'PID' is NaN
result_df.dropna(subset=['PID'], inplace=True)

# %%
print(result_df.info())
print(result_df['Source_File'].unique())
print(len(result_df['Source_File'].unique()))
print(result_df['PID'].unique())
print(len(result_df['PID'].unique()))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 209498 entries, 8 to 211842
# Data columns (total 18 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   Relative Time (sec)  209498 non-null  int64
#  1   Time                 209498 non-null  object
#  2   PEEP_Actual          209498 non-null  float64
#  3   AVEA - Set: iVT      209498 non-null  float64
#  4   Tidal_Volume         209498 non-null  float64
#  5   PIP_Actual           209498 non-null  float64
#  6   PEEP_Settings        209498 non-null  float64
#  7   AVEA - Pplat         0 non-null       float64
#  8   AVEA - Set: Pinsp    209498 non-null  float64
#  9   Hour                 209498 non-null  int64
#  10  Time_Stamp           209498 non-null  object
#  11  Time_Stamp_2         209498 non-null  object
#  12  Source_File          209498 non-null  object
#  13  PIP_Settings         209498 non-null  float64
# ...

# %%
# Print the count of NaN values in 'TV(mL/kg)' and 'TV(mL/kg)_ma'
print(result_df['TV(mL/kg)'].isna().sum())
print(result_df['TV(mL/kg)_ma'].isna().sum())
# Out:
# 0
# 0

# %%
print(result_df['TV(mL/kg)'].min())
print(result_df['TV(mL/kg)_ma'].min())
# Out:
# 0.0
# 0.0009275671627819902

# %%
AVEAA_PCM_df = result_df
AVEAA_PCM_df
# Out:
#         Relative Time (sec)                     Time  PEEP_Actual  \
# 8                        47  2023-11-01 13:10:47.000          6.0
# 9                        48  2023-11-01 13:10:48.000          6.0
# 10                       50  2023-11-01 13:10:50.000          6.0
# 11                       53  2023-11-01 13:10:53.000          6.0
# 12                       55  2023-11-01 13:10:55.000          6.0
# ...                     ...                      ...          ...
# 211838                86389  2023-12-19 21:08:49.000         10.0
# 211839                86391  2023-12-19 21:08:51.000         10.0
# 211840                86394  2023-12-19 21:08:54.000         10.0
# 211841                86396  2023-12-19 21:08:56.000         10.0
# 211842                86399  2023-12-19 21:08:59.000         10.0
#
#         AVEA - Set: iVT  Tidal_Volume  PIP_Actual  PEEP_Settings  \
# 8                  25.0    142.840607        26.0            6.0
# ...

# %%
len(AVEAA_PCM_df['PID'].unique())
# Out:
# 8

# %%
len(AVEAA_PCM_df['Source_File'].unique())
# Out:
# 8

# %%
# %store AVEAA_PCM_df
# Out:
# Stored 'AVEAA_PCM_df' (DataFrame)

# %%
# ### Abnormal values detection for result_df['TV(mL/kg)']

# print(result_df.info())
# print(len(result_df['PID'].unique()))
# print(len(result_df['Weight'].unique()))

# # Filter rows where 'TV(mL/kg)' is greater than 25
# filtered_df = result_df[result_df['TV(mL/kg)'] > 25]

# # Display specific columns for the filtered rows
# relevant_columns = ['PID', 'Time', 'PIP_Settings', 'Tidal_Volume', 'TV(mL/kg)', 'Weight']
# filtered_data = filtered_df[relevant_columns]
# filtered_data['PID'] = filtered_data['PID'].astype(int)

# # Print or display the filtered data
# print(filtered_data.info())
# print(filtered_data['PID'].astype(int).unique())

# # Define the file path where you want to save the CSV file
# csv_file_path = 'AVEAA_TV_GreaterThan_25.csv'

# # Save the filtered data to a CSV file
# filtered_data.to_csv(csv_file_path, index=False)

# %%
# Violinplot for all AVEAA by PIP Settings

# Set the size of the plot
plt.figure(figsize=(20, 10))

# Create violin plot
sns.violinplot(data=result_df, x='PIP_Settings', y='TV(mL/kg)_ma', hue='PIP_Settings', palette='muted', legend=False)
plt.xlabel('PIP Settings (cmH2O)', fontsize=16)
plt.ylabel('Tidal Volume (mL/kg)', fontsize=16)
plt.title('CDGR Ventilator: Tidal Volume Distribution across PIP Settings', fontsize=20)

# Add thresholds for Volume in violin plot
plt.axhline(y=6, color='r', linestyle='--', linewidth=1, label='Tidal Volume = 6 mL/kg')
plt.axhline(y=8, color='b', linestyle='--', linewidth=1, label='Tidal Volume = 8 mL/kg')

# Find the index corresponding to PIP Setting of 28.0
# Get unique PIP_Settings values and drop NaN
x_index = result_df['PIP_Settings'].dropna().unique()
# Sort the unique values in ascending order
x_index.sort()
# Find the index corresponding to PIP Setting of 28.0
pip_28_index = np.where(x_index == 28.0)[0][0]
# Add vertical line at x=28.0
plt.axvline(x=pip_28_index, color='g', linestyle='--', linewidth=2, label='PIP Setting = 28 cmH2O')

plt.xticks(fontsize=12)
plt.yticks(fontsize=12)

# plt.legend()
# plt.legend()
plt.legend(title='Legend', bbox_to_anchor=(1, 1), loc='upper left', fontsize=16)

plt.show()

# %%
# PIP Settings v.s Tidal Volume in time series for the Pressure Control Mode cohort
## AVEAA (all) -- Violinplot(Boxplot) + Table

import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming df is your existing DataFrame
# Ensure df has 'TV(mL/kg)', 'PIP_Settings', and 'Time' columns
df = result_df
# print(df.info())

# Calculate average, minimum, and maximum PIP Settings per hour
pip_stats_per_hour = df.groupby('Time_Stamp_2')['PIP_Settings'].agg(['mean', 'min', 'max']).round().astype(int)
# Rename the columns for clarity
pip_stats_per_hour.rename(columns={'mean': 'Average_PIP_Settings', 'min': 'Min_PIP_Settings', 'max': 'Max_PIP_Settings'}, inplace=True)
# print(pip_stats_per_hour)

# # Calculate average tidal volume at 8 am
# eight_am_data = df[(df['Time'].dt.time >= pd.to_datetime('08:00:00').time()) & 
#                    (df['Time'].dt.time <= pd.to_datetime('08:01:00').time())]
# eight_am_avg = eight_am_data['TV(mL/kg)'].mean()

# Plotting
fig, ax = plt.subplots(figsize=(20, 10))

# Violin plot for Tidal Volume by Hour
sns.violinplot(ax=ax, x='Time_Stamp_2', y='TV(mL/kg)', data=df, inner='box', hue='Time_Stamp_2', palette='muted', legend=False)

# # Box plot for Tidal Volume by Hour
# sns.boxplot(ax=ax, x='Time_Stamp_2', y='TV(mL/kg)_ma', data=df, hue='Time_Stamp_2', palette='muted', showfliers=False)

# Add thresholds for Volume in violin plot
ax.axhline(y=6, color='g', linestyle='--', linewidth=1, label='Tidal Volume = 6 mL/kg')
ax.axhline(y=8, color='g', linestyle='--', linewidth=1, label='Tidal Volume = 8 mL/kg')

# Add light green background between the two lines
ax.axhspan(ymin=6, ymax=8, color='lightgreen', alpha=0.3)

# Add legend
# ax.legend()
ax.legend(title='Legend', bbox_to_anchor=(1, 1), loc='upper left', fontsize=16)

# Add a title for the violin plot
ax.set_title('Tidal Volume by Hour', pad=18, fontsize=20)  # Increase pad to adjust title position

# Title and labels for the violin plot
ax.set_ylabel('Tidal Volume (mL/kg)', fontsize=16)
ax.set_xlabel('Hour', fontsize=16)

# Create custom labels for the x-axis
# custom_labels = ['{}am'.format(hour) if hour < 12 else '{}pm'.format(hour - 12) for hour in range(24)]
# custom_labels[0] = '12am'
# custom_labels[12] = '12pm'
custom_labels = df['Time_Stamp_2'].unique()
custom_labels = sorted(custom_labels, key=lambda x: int(x[1:]))

# Set custom x-axis labels (bottom x-axis)
ax.set_xticks(range(24))
ax.set_xticklabels(custom_labels)
ax.tick_params(axis='x', labelsize=16)
ax.tick_params(axis='y', labelsize=16)

# # Hide x-axis ticks
# ax.xaxis.set_ticks([])

# Custom function to format table cells
def format_table_cell(value):
    if value > 28:
        return 'red'
    else:
        return 'white'

# Create formatted table data
formatted_table_data = [
    [pip_stats_per_hour['Min_PIP_Settings'].get(hour, 0) for hour in range(24)],
    [pip_stats_per_hour['Average_PIP_Settings'].get(hour, 0) for hour in range(24)],
    [pip_stats_per_hour['Max_PIP_Settings'].get(hour, 0) for hour in range(24)]
]

# Create cell colors based on the value
cell_colors = []
for row in formatted_table_data:
    color_row = [format_table_cell(value) for value in row]
    cell_colors.append(color_row)

# Define custom labels for the rows and columns
row_labels = ['Min', 'Average', 'Max']
# col_labels = [f'{hour}am' if hour < 12 else f'{hour - 12}pm' for hour in range(24)]
# col_labels[0] = '12am'
# col_labels[12] = '12pm'
col_labels = df['Time_Stamp_2'].unique()
col_labels = sorted(col_labels, key=lambda x: int(x[1:]))

# Create a table to display min, average, and max PIP Settings
table_pos = [0.025, -0.35, 0.95, 0.2]  # Adjust the bbox position (left, bottom, width, height)
table = ax.table(cellText=formatted_table_data,
                 rowLabels=row_labels,
                 colLabels=col_labels,
                 cellLoc='center',
                 cellColours=cell_colors,
                 loc='bottom', 
                 bbox=table_pos)

# Adjust table properties
table.auto_set_font_size(False)
table.set_fontsize(16)
table.scale(1, 1.5)

# Add a title for the table
table_title = plt.text(0.5, -0.12, 'Min, Average, and Max PIP Settings by Hour', horizontalalignment='center', verticalalignment='center',
                       transform=ax.transAxes, fontsize=20)

# Add legend for red text indicating PIP Settings > 28
legend_text = '* Red text: PIP Settings > 28 cmH2O'
plt.figtext(0.1, -0.01, legend_text, wrap=True, horizontalalignment='center', fontsize=12, color='red')

# Adjust layout
plt.tight_layout()

# Show plot
plt.show()

# %%
# PIP Settings v.s Tidal Volume in time series for the Pressure Control Mode cohort
## AVEAA (all) -- Violinplot(Boxplot) + Boxplot

import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming df is your existing DataFrame
# Ensure df has 'TV(mL/kg)', 'PIP_Settings', and 'Hour' columns
df = result_df

# Create subplots
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(20, 10), sharex=True, gridspec_kw={'height_ratios': [2, 1]})

# Violin plot for Tidal Volume by Hour
sns.violinplot(ax=ax1, x='Time_Stamp_2', y='TV(mL/kg)_ma', data=df, inner='box', hue='Time_Stamp_2', palette='muted', legend=False)

# # Box plot for Tidal Volume by Hour
# sns.boxplot(ax=ax1, x='Time_Stamp_2', y='TV(mL/kg)', data=df, hue='Time_Stamp_2', palette='muted', showfliers=False)

# Add thresholds for Volume in violin plot
ax1.axhline(y=6, color='g', linestyle='--', linewidth=1, label='Tidal Volume = 6 mL/kg')
ax1.axhline(y=8, color='g', linestyle='--', linewidth=1, label='Tidal Volume = 8 mL/kg')

# Add light green background between the two lines
ax1.axhspan(ymin=6, ymax=8, color='lightgreen', alpha=0.3)

# # Add legend
# ax1.legend()

# Adding legend for the markers
ax1.legend(title='Legend', bbox_to_anchor=(1, 1), loc='upper left', fontsize=16)

# Add a title for the violin plot
ax1.set_title('Tidal Volume by Hour', pad=18, fontsize=20)  # Increase pad to adjust title position

# Title and labels for the violin plot
ax1.set_ylabel('Tidal Volume (mL/kg)', fontsize=16)

# Boxplot for PIP Settings by Hour
sns.boxplot(ax=ax2, x='Time_Stamp_2', y='PIP_Settings', data=df, hue='Time_Stamp_2', palette='muted', legend=False)

# Add threshold line for PIP Settings = 28
ax2.axhline(y=28, color='r', linestyle='--', linewidth=1, label='PIP Settings = 28 cmH2O')

# # Add legend
# ax2.legend()

# Adding legend for the markers
ax2.legend(title='Legend', bbox_to_anchor=(1, 1), loc='upper left', fontsize=16)

# Add a title for the boxplot
ax2.set_title('PIP Settings by Hour', pad=18, fontsize=20)  # Increase pad to adjust title position

# Title and labels for the boxplot
ax2.set_ylabel('PIP Settings (cmH2O)', fontsize=16)
ax2.set_xlabel('Hour', fontsize=16)

# Create custom labels for the x-axis
# custom_labels = ['{}am'.format(hour) if hour < 12 else '{}pm'.format(hour - 12) for hour in range(24)]
# custom_labels[0] = '12am'
# custom_labels[12] = '12pm'
custom_labels = df['Time_Stamp_2'].unique()
custom_labels = sorted(custom_labels, key=lambda x: int(x[1:]))

# Set custom x-axis labels (bottom x-axis)
ax2.set_xticks(range(24))
ax2.set_xticklabels(custom_labels)
ax2.tick_params(axis='x', labelsize=16)
ax2.tick_params(axis='y', labelsize=16)

# Adjust layout
plt.tight_layout()

# Show plot
plt.show()

# %%
# Combine all data together
import pandas as pd

# Convert PIP_Settings from mbar to cmH2O in CDGR_df
CDGR_PCM_df['PIP_Settings'] = CDGR_PCM_df['PIP_Settings'] * 1.01972
CDGR_VCM_df['PIP_Settings'] = CDGR_VCM_df['PIP_Settings'] * 1.01972

# Concatenate CDGR_PCM_df, CDGR_VCM_df, and AVEAA_df vertically
combined_df = pd.concat([CDGR_PCM_df, CDGR_VCM_df, AVEAA_PCM_df], axis=0)

# Select only the specified columns
columns_to_keep = ["Time", "Time_Stamp", "Time_Stamp_2", "PID", "PIP_Settings", "Volume_Settings", "Tidal_Volume", "TV(mL/kg)", "TV(mL/kg)_ma", "Weight", "Source_File"]
combined_df = combined_df[columns_to_keep]

# Reset the index of the combined dataframe (optional, depending on your use case)
combined_df.reset_index(drop=True, inplace=True)

# Display the combined dataframe
combined_df
# Out:
#                             Time Time_Stamp Time_Stamp_2        PID  \
# 0            2023-11-07 06:38:53        6am           H7   146235.0
# 1            2023-11-07 06:38:55        6am           H7   146235.0
# 2            2023-11-07 06:38:57        6am           H7   146235.0
# 3            2023-11-07 06:38:59        6am           H7   146235.0
# 4            2023-11-07 06:39:00        6am           H7   146235.0
# ...                          ...        ...          ...        ...
# 2890212  2023-12-19 21:08:49.000        9pm          H22  1026178.0
# 2890213  2023-12-19 21:08:51.000        9pm          H22  1026178.0
# 2890214  2023-12-19 21:08:54.000        9pm          H22  1026178.0
# 2890215  2023-12-19 21:08:56.000        9pm          H22  1026178.0
# 2890216  2023-12-19 21:08:59.000        9pm          H22  1026178.0
#
#          PIP_Settings  Volume_Settings  Tidal_Volume  TV(mL/kg)  TV(mL/kg)_ma  \
# ...

# %%
len(combined_df['PID'].unique())
# Out:
# 56

# %%
len(combined_df['Source_File'].unique())
# Out:
# 57

# %%
import pandas as pd

# Load the CSV file into a DataFrame
file_path = 'EHR_data.csv'
data = pd.read_csv(file_path)

# Display the first few rows of the DataFrame
print(data.head())
# Out:
#    Cohort Ventilator      PID        MRN  vari_date  vari_ards  \
# 0      58      AVEAA    76598  101532084  18-Dec-23          0
# 1      58      AVEAA   132310  101675324   1-Nov-23          1
# 2      58      AVEAA   606288  101149608  19-Dec-23          0
# 3      58      AVEAA  1026178  101890492  18-Dec-23          1
# 4      58       CDGR     2951  101336219   4-Oct-23          0
#
#    vari_age_months  vari_age_years  vari_weight  \
# 0              707        1.936986         6.08
# 1             2018        5.528767         9.84
# 2             1957        5.361644        13.56
# 3             1005        2.753425         5.49
# 4             2884        7.901370        27.35
#
#                                  Mode Category                 File Name  \
# 0  Pressure Control (or Volume Guarantee) Mode  a_58_AVEAA_4_1st (1).csv
# 1  Pressure Control (or Volume Guarantee) Mode  a_58_AVEAA_4_1st (2).csv
# ...

# %%
# Merge the 'vari_ards' column from data into combined_df based on 'File Name 2' and 'Source_File' columns
combined_df = combined_df.merge(data[['File Name 2', 'vari_date', 'vari_ards',
                                              'vari_age_months', 'vari_age_years', 'vari_weight']], 
                                        left_on='Source_File', right_on='File Name 2', how='left')

# Drop the 'File Name 2' column as it's not needed in the final combined_df
combined_df.drop(columns=['File Name 2'], inplace=True)

# Display the first few rows of the updated combined_df
print(combined_df.head())
# Out:
#                   Time Time_Stamp Time_Stamp_2       PID  PIP_Settings  \
# 0  2023-11-07 06:38:53        6am           H7  146235.0       30.5916
# 1  2023-11-07 06:38:55        6am           H7  146235.0       30.5916
# 2  2023-11-07 06:38:57        6am           H7  146235.0       30.5916
# 3  2023-11-07 06:38:59        6am           H7  146235.0       30.5916
# 4  2023-11-07 06:39:00        6am           H7  146235.0       35.6902
#
#    Volume_Settings  Tidal_Volume  TV(mL/kg)  TV(mL/kg)_ma  Weight  \
# 0              NaN          73.0   4.614412      4.614412   15.82
# 1              NaN          73.0   4.614412      4.614412   15.82
# 2              NaN          60.0   3.792668      4.340497   15.82
# 3              NaN          60.0   3.792668      4.203540   15.82
# 4              NaN          60.0   3.792668      4.121365   15.82
#
#                    Source_File vari_date  vari_ards  vari_age_months  \
# ...

# %%
combined_df['vari_ards'].groupby(combined_df['Source_File']).unique()
# Out:
# Source_File
# a_58_AVEAA_4_24hrs (1).csv      [0]
# a_58_AVEAA_4_24hrs (2).csv      [1]
# a_58_AVEAA_4_24hrs (3).csv      [0]
# a_58_AVEAA_4_24hrs (4).csv      [1]
# a_58_CDGR_39_24hrs (1).csv      [0]
# a_58_CDGR_39_24hrs (11).csv     [0]
# a_58_CDGR_39_24hrs (12).csv     [1]
# a_58_CDGR_39_24hrs (13).csv     [1]
# a_58_CDGR_39_24hrs (14).csv     [0]
# a_58_CDGR_39_24hrs (15).csv     [1]
# a_58_CDGR_39_24hrs (16).csv     [0]
# a_58_CDGR_39_24hrs (17).csv     [0]
# a_58_CDGR_39_24hrs (18).csv     [1]
# a_58_CDGR_39_24hrs (19).csv     [0]
# a_58_CDGR_39_24hrs (2).csv      [0]
# a_58_CDGR_39_24hrs (20).csv     [1]
# a_58_CDGR_39_24hrs (21).csv     [1]
# a_58_CDGR_39_24hrs (22).csv     [0]
# a_58_CDGR_39_24hrs (23).csv     [0]
# a_58_CDGR_39_24hrs (24).csv     [1]
# a_58_CDGR_39_24hrs (25).csv     [1]
# a_58_CDGR_39_24hrs (26).csv     [1]
# a_58_CDGR_39_24hrs (27).csv     [0]
# a_58_CDGR_39_24hrs (28).csv     [0]
# a_58_CDGR_39_24hrs (29).csv     [1]
# ...

# %%
combined_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2890217 entries, 0 to 2890216
# Data columns (total 16 columns):
#  #   Column           Dtype
# ---  ------           -----
#  0   Time             object
#  1   Time_Stamp       object
#  2   Time_Stamp_2     object
#  3   PID              float64
#  4   PIP_Settings     float64
#  5   Volume_Settings  float64
#  6   Tidal_Volume     float64
#  7   TV(mL/kg)        float64
#  8   TV(mL/kg)_ma     float64
#  9   Weight           float64
#  10  Source_File      object
#  11  vari_date        object
#  12  vari_ards        int64
#  13  vari_age_months  int64
#  14  vari_age_years   float64
#  15  vari_weight      float64
# dtypes: float64(9), int64(2), object(5)
# memory usage: 374.9+ MB

# %%
# PIP Settings v.s Tidal Volume in time series for the Pressure Control Mode cohort
## ALL DATA -- Violinplot(Boxplot) + Table

import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming df is your existing DataFrame
# Ensure df has 'TV(mL/kg)', 'PIP_Settings', and 'Time' columns
df = combined_df
# print(df.info())

# Calculate average, minimum, and maximum PIP Settings per hour
pip_stats_per_hour = df.groupby('Time_Stamp_2')['PIP_Settings'].agg(['mean', 'min', 'max']).round().astype(int)
# Rename the columns for clarity
pip_stats_per_hour.rename(columns={'mean': 'Average_PIP_Settings', 'min': 'Min_PIP_Settings', 'max': 'Max_PIP_Settings'}, inplace=True)
# print(pip_stats_per_hour)

# # Calculate average tidal volume at 8 am
# eight_am_data = df[(df['Time'].dt.time >= pd.to_datetime('08:00:00').time()) & 
#                    (df['Time'].dt.time <= pd.to_datetime('08:01:00').time())]
# eight_am_avg = eight_am_data['TV(mL/kg)'].mean()

# Plotting
fig, ax = plt.subplots(figsize=(20, 10))

# Violin plot for Tidal Volume by Hour
sns.violinplot(ax=ax, x='Time_Stamp_2', y='TV(mL/kg)_ma', data=df, inner='box', hue='Time_Stamp_2', palette='muted', legend=False)

# # Box plot for Tidal Volume by Hour
# sns.boxplot(ax=ax, x='Time_Stamp_2', y='TV(mL/kg)_ma', data=df, hue='Time_Stamp_2', palette='muted', showfliers=False)

# Add thresholds for Volume in violin plot
ax.axhline(y=6, color='g', linestyle='--', linewidth=1, label='Tidal Volume = 6 mL/kg')
ax.axhline(y=8, color='g', linestyle='--', linewidth=1, label='Tidal Volume = 8 mL/kg')

# Add light green background between the two lines
ax.axhspan(ymin=6, ymax=8, color='lightgreen', alpha=0.3)

# Add legend
# ax.legend()
ax.legend(title='Legend', bbox_to_anchor=(1, 1), loc='upper left', fontsize=16)

# Add a title for the violin plot
ax.set_title('Tidal Volume by Hour', pad=18, fontsize=20)  # Increase pad to adjust title position

# Title and labels for the violin plot
ax.set_ylabel('Tidal Volume (mL/kg)', fontsize=16)
ax.set_xlabel('Hour', fontsize=16)

# Create custom labels for the x-axis
# custom_labels = ['{}am'.format(hour) if hour < 12 else '{}pm'.format(hour - 12) for hour in range(24)]
# custom_labels[0] = '12am'
# custom_labels[12] = '12pm'
custom_labels = df['Time_Stamp_2'].unique()
custom_labels = sorted(custom_labels, key=lambda x: int(x[1:]))

# Set custom x-axis labels (bottom x-axis)
ax.set_xticks(range(24))
ax.set_xticklabels(custom_labels)
ax.tick_params(axis='x', labelsize=16)
ax.tick_params(axis='y', labelsize=16)

# # Hide x-axis ticks
ax.xaxis.set_ticks([])

# Custom function to format table cells
def format_table_cell(value):
    if value > 28:
        return 'red'
    else:
        return 'white'

# Create formatted table data
formatted_table_data = [
    [pip_stats_per_hour['Min_PIP_Settings'].get(hour, 0) for hour in range(24)],
    [pip_stats_per_hour['Average_PIP_Settings'].get(hour, 0) for hour in range(24)],
    [pip_stats_per_hour['Max_PIP_Settings'].get(hour, 0) for hour in range(24)]
]

# Create cell colors based on the value
cell_colors = []
for row in formatted_table_data:
    color_row = [format_table_cell(value) for value in row]
    cell_colors.append(color_row)

# Define custom labels for the rows and columns
row_labels = ['Min', 'Average', 'Max']
# col_labels = [f'{hour}am' if hour < 12 else f'{hour - 12}pm' for hour in range(24)]
# col_labels[0] = '12am'
# col_labels[12] = '12pm'
col_labels = df['Time_Stamp_2'].unique()
col_labels = sorted(col_labels, key=lambda x: int(x[1:]))

# Create a table to display min, average, and max PIP Settings
table_pos = [0.025, -0.35, 0.95, 0.2]  # Adjust the bbox position (left, bottom, width, height)
table = ax.table(cellText=formatted_table_data,
                 rowLabels=row_labels,
                 colLabels=col_labels,
                 cellLoc='center',
                 cellColours=cell_colors,
                 loc='bottom', 
                 bbox=table_pos)

# Adjust table properties
table.auto_set_font_size(False)
table.set_fontsize(16)
table.scale(1, 1.5)

# Add a title for the table
table_title = plt.text(0.5, -0.12, 'Min, Average, and Max PIP Settings by Hour', horizontalalignment='center', verticalalignment='center',
                       transform=ax.transAxes, fontsize=20)

# Add legend for red text indicating PIP Settings > 28
legend_text = '* Red text: PIP Settings > 28 cmH2O'
plt.figtext(0.1, -0.01, legend_text, wrap=True, horizontalalignment='center', fontsize=12, color='red')

# Adjust layout
plt.tight_layout()

# Show plot
plt.show()

# %%
# PIP Settings v.s Tidal Volume in time series for the Pressure Control Mode cohort
## ALL DATA -- Violinplot(Boxplot) + Boxplot

import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming df is your existing DataFrame
# Ensure df has 'TV(mL/kg)', 'PIP_Settings', and 'Hour' columns
df = combined_df

# Create subplots
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(20, 10), sharex=True, gridspec_kw={'height_ratios': [2, 1]})

# Violin plot for Tidal Volume by Hour
sns.violinplot(ax=ax1, x='Time_Stamp_2', y='TV(mL/kg)_ma', data=df, inner='box', hue='Time_Stamp_2', palette='muted', legend=False)

# # Box plot for Tidal Volume by Hour
# sns.boxplot(ax=ax1, x='Time_Stamp_2', y='TV(mL/kg)', data=df, hue='Time_Stamp_2', palette='muted', showfliers=False)

# Add thresholds for Volume in violin plot
ax1.axhline(y=6, color='g', linestyle='--', linewidth=1, label='Tidal Volume = 6 mL/kg')
ax1.axhline(y=8, color='g', linestyle='--', linewidth=1, label='Tidal Volume = 8 mL/kg')

# Add light green background between the two lines
ax1.axhspan(ymin=6, ymax=8, color='lightgreen', alpha=0.3)

# # Add legend
# ax1.legend()

# Adding legend for the markers
ax1.legend(title='Legend', bbox_to_anchor=(1, 1), loc='upper left', fontsize=16)

# Add a title for the violin plot
ax1.set_title('Tidal Volume by Hour', pad=18, fontsize=20)  # Increase pad to adjust title position

# Title and labels for the violin plot
ax1.set_ylabel('Tidal Volume (mL/kg)', fontsize=16)

# Boxplot for PIP Settings by Hour
sns.boxplot(ax=ax2, x='Time_Stamp_2', y='PIP_Settings', data=df, hue='Time_Stamp_2', palette='muted', legend=False)

# Add threshold line for PIP Settings = 28
ax2.axhline(y=28, color='r', linestyle='--', linewidth=1, label='PIP Settings = 28 cmH2O')

# # Add legend
# ax2.legend()

# Adding legend for the markers
ax2.legend(title='Legend', bbox_to_anchor=(1, 1), loc='upper left', fontsize=16)

# Add a title for the boxplot
ax2.set_title('PIP Settings by Hour', pad=18, fontsize=20)  # Increase pad to adjust title position

# Title and labels for the boxplot
ax2.set_ylabel('PIP Settings (cmH2O)', fontsize=16)
ax2.set_xlabel('Hour', fontsize=16)

# Create custom labels for the x-axis
# custom_labels = ['{}am'.format(hour) if hour < 12 else '{}pm'.format(hour - 12) for hour in range(24)]
# custom_labels[0] = '12am'
# custom_labels[12] = '12pm'
custom_labels = df['Time_Stamp_2'].unique()
custom_labels = sorted(custom_labels, key=lambda x: int(x[1:]))

# Set custom x-axis labels (bottom x-axis)
ax2.set_xticks(range(24))
ax2.set_xticklabels(custom_labels)
ax2.tick_params(axis='x', labelsize=16)
ax2.tick_params(axis='y', labelsize=16)

# Adjust layout
plt.tight_layout()

# Show plot
plt.show()

# %%
pards_descriptive_df = combined_df
# %store pards_descriptive_df
# Out:
# Stored 'pards_descriptive_df' (DataFrame)

# %% [markdown]
# ##############################################

# %%
# %store -r pards_descriptive_df
pards_descriptive_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2890217 entries, 0 to 2890216
# Data columns (total 16 columns):
#  #   Column           Dtype
# ---  ------           -----
#  0   Time             object
#  1   Time_Stamp       object
#  2   Time_Stamp_2     object
#  3   PID              float64
#  4   PIP_Settings     float64
#  5   Volume_Settings  float64
#  6   Tidal_Volume     float64
#  7   TV(mL/kg)        float64
#  8   TV(mL/kg)_ma     float64
#  9   Weight           float64
#  10  Source_File      object
#  11  vari_date        object
#  12  vari_ards        int64
#  13  vari_age_months  int64
#  14  vari_age_years   float64
#  15  vari_weight      float64
# dtypes: float64(9), int64(2), object(5)
# memory usage: 374.9+ MB

# %%
pards_descriptive_df
# Out:
#                             Time Time_Stamp Time_Stamp_2        PID  \
# 0            2023-11-07 06:38:53        6am           H7   146235.0
# 1            2023-11-07 06:38:55        6am           H7   146235.0
# 2            2023-11-07 06:38:57        6am           H7   146235.0
# 3            2023-11-07 06:38:59        6am           H7   146235.0
# 4            2023-11-07 06:39:00        6am           H7   146235.0
# ...                          ...        ...          ...        ...
# 2890212  2023-12-19 21:08:49.000        9pm          H22  1026178.0
# 2890213  2023-12-19 21:08:51.000        9pm          H22  1026178.0
# 2890214  2023-12-19 21:08:54.000        9pm          H22  1026178.0
# 2890215  2023-12-19 21:08:56.000        9pm          H22  1026178.0
# 2890216  2023-12-19 21:08:59.000        9pm          H22  1026178.0
#
#          PIP_Settings  Volume_Settings  Tidal_Volume  TV(mL/kg)  TV(mL/kg)_ma  \
# ...

# %%
len(pards_descriptive_df['Source_File'].unique())
# Out:
# 57

# %%
#  TV Stats Summary
import pandas as pd

# Filter rows where 'Time_Stamp' is '8am' or 'Time_Stamp_2' is 'H9':
# filtered_df = pards_descriptive_df[pards_descriptive_df['Time_Stamp'] == '8am']
# filtered_df = pards_descriptive_df[pards_descriptive_df['Time_Stamp_2'] == 'H9']
# filtered_df = pards_descriptive_df[(pards_descriptive_df['Time_Stamp_2'] == 'H9') & 
#                                    (pards_descriptive_df['vari_ards'] == 1)]
# filtered_df = pards_descriptive_df[(pards_descriptive_df['Time_Stamp_2'] == 'H9') & 
#                                    (pards_descriptive_df['vari_ards'] == 0)]

# filtered_df = pards_descriptive_df
# filtered_df = pards_descriptive_df[(pards_descriptive_df['vari_ards'] == 1)]

# Define function to calculate IQR
def calculate_iqr(series):
    """Calculate the interquartile range (IQR) of a pandas Series."""
    Q1 = series.quantile(0.25)
    Q3 = series.quantile(0.75)
    return Q3 - Q1

# Calculate overall median and IQR for 'TV(mL/kg)_ma' at 'H9'
overall_mean = filtered_df['TV(mL/kg)_ma'].mean()
overall_std = filtered_df['TV(mL/kg)_ma'].std()
overall_median = filtered_df['TV(mL/kg)_ma'].median()
overall_iqr = calculate_iqr(filtered_df['TV(mL/kg)_ma'])

# Print overall statistics
print(f"Overall mean TV(mL/kg)_ma: {overall_mean:.2f}")
print(f"Overall std TV(mL/kg)_ma: {overall_std:.2f}")
print(f"Overall median TV(mL/kg)_ma: {overall_median:.2f}")
print(f"Overall IQR TV(mL/kg)_ma: {overall_iqr:.2f}")
# Out:
# Overall mean TV(mL/kg)_ma: 11.53
# Overall std TV(mL/kg)_ma: 3.65
# Overall median TV(mL/kg)_ma: 11.11
# Overall IQR TV(mL/kg)_ma: 5.79

# %%
#  TV Stats Summary (Cont'd)
import pandas as pd

# filtered_df = pards_descriptive_df[pards_descriptive_df['Time_Stamp_2'] == 'H9']
filtered_df = pards_descriptive_df[(pards_descriptive_df['Time_Stamp_2'] == 'H9') & 
                                   (pards_descriptive_df['vari_ards'] == 1)]
# filtered_df = pards_descriptive_df[(pards_descriptive_df['Time_Stamp_2'] == 'H9') & 
#                                    (pards_descriptive_df['vari_ards'] == 0)]

# filtered_df = pards_descriptive_df
# filtered_df = pards_descriptive_df[(pards_descriptive_df['vari_ards'] == 1)]

# # Calculate the portion of 'TV(mL/kg)_ma' values less than 8
# portion = 1 - (filtered_df['TV(mL/kg)_ma'] < 8).sum() / len(filtered_df)

# Calculate the portion of 'TV(mL/kg)_ma' values between 6 and 8
portion = ((filtered_df['TV(mL/kg)_ma'] < 8)&(filtered_df['TV(mL/kg)_ma'] > 6)).sum() / len(filtered_df)

print(f"Portion of TV(mL/kg)_ma : {portion:.2%}")
# Out:
# Portion of TV(mL/kg)_ma : 6.74%

# %%
#  PIP Settings Stats Summary
import pandas as pd

# Ensure 'Time_Stamp_2' is in the correct format and filter rows where 'Time_Stamp_2' is 'H9'
# filtered_df = pards_descriptive_df[pards_descriptive_df['Time_Stamp_2'] == 'H9']
filtered_df = pards_descriptive_df[(pards_descriptive_df['Time_Stamp_2'] == 'H9') & 
                                   (pards_descriptive_df['vari_ards'] == 1)]
# filtered_df = pards_descriptive_df[(pards_descriptive_df['Time_Stamp_2'] == 'H9') & 
#                                    (pards_descriptive_df['vari_ards'] == 0)]

# filtered_df = pards_descriptive_df
# filtered_df = pards_descriptive_df[(pards_descriptive_df['vari_ards'] == 1)]

# Define function to calculate IQR
def calculate_iqr(series):
    """Calculate the interquartile range (IQR) of a pandas Series."""
    Q1 = series.quantile(0.25)
    Q3 = series.quantile(0.75)
    return Q3 - Q1

# Calculate overall median and IQR for 'TV(mL/kg)_ma' at 'H9'
overall_mean = filtered_df['PIP_Settings'].mean()
overall_std = filtered_df['PIP_Settings'].std()
overall_median = filtered_df['PIP_Settings'].median()
overall_iqr = calculate_iqr(filtered_df['PIP_Settings'])

# Print overall statistics
print(f"Overall mean PIP_Settings: {overall_mean:.2f}")
print(f"Overall std PIP_Settingsa: {overall_std:.2f}")
print(f"Overall median PIP_Settings: {overall_median:.2f}")
print(f"Overall IQR PIP_Settings: {overall_iqr:.2f}")
# Out:
# Overall mean PIP_Settings: 25.23
# Overall std PIP_Settingsa: 7.02
# Overall median PIP_Settings: 24.47
# Overall IQR PIP_Settings: 6.12

# %%
#  PIP Settings Stats Summary (Cont'd)
import pandas as pd

# Ensure 'Time_Stamp_2' is in the correct format and filter rows where 'Time_Stamp_2' is 'H9'
# filtered_df = pards_descriptive_df[pards_descriptive_df['Time_Stamp_2'] == 'H9']
filtered_df = pards_descriptive_df[(pards_descriptive_df['Time_Stamp_2'] == 'H9') & 
                                   (pards_descriptive_df['vari_ards'] == 1)]
# filtered_df = pards_descriptive_df[(pards_descriptive_df['Time_Stamp_2'] == 'H9') & 
#                                    (pards_descriptive_df['vari_ards'] == 0)]

# filtered_df = pards_descriptive_df
# filtered_df = pards_descriptive_df[(pards_descriptive_df['vari_ards'] == 1)]

# Calculate the portion of 'TV(mL/kg)_ma' values greater than 28
portion = 1 - (filtered_df['PIP_Settings'] > 28).sum() / len(filtered_df)

print(f"Portion of PIP_Settings: {portion:.2%}")
# Out:
# Portion of PIP_Settings: 77.89%

# %%
# Figure 1
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import os

output_dir = '/nfs/turbo/med-kayvan-lab/Projects/PARDS/04-Results/PARDS_Descriptive'
os.makedirs(output_dir, exist_ok=True)

df = pards_descriptive_df.copy()  # Make a copy to avoid modifying the original DataFrame

# Rename 'vari_ards' values
df['vari_ards'] = df['vari_ards'].apply(lambda x: 'ARDS' if x == 1 else 'Non-ARDS')

# Create subplots
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(30, 10), sharex=True, 
                               gridspec_kw={'height_ratios': [2, 1]})

# Define dark blue and light gray colors
colors = ['#1f77b4', '#d3d3d3']  # Dark blue and light gray

# Violin plot for Tidal Volume by Hour with 'vari_ards' distinction
sns.violinplot(ax=ax1, x='Time_Stamp_2', y='TV(mL/kg)_ma', 
               hue='vari_ards', data=df, split=True, inner='box', palette=colors)

# Add thresholds for Volume in violin plot
ax1.axhline(y=6, color='g', linestyle='--', linewidth=1, label='Tidal Volume = 6 mL/kg')
ax1.axhline(y=8, color='g', linestyle='--', linewidth=1, label='Tidal Volume = 8 mL/kg')

# Add light green background between the two lines
ax1.axhspan(ymin=6, ymax=8, color='lightgreen', alpha=0.3)

# Adding legend for the markers
ax1.legend(bbox_to_anchor=(1, 1), loc='upper left', fontsize=20)

# Add a title for the violin plot
ax1.set_title('Tidal Volume (TV) by Hour with ARDS Distinction', pad=18, fontsize=28)  # Increase pad to adjust title position

# Title and labels for the violin plot
ax1.set_ylabel('Tidal Volume (TV) (mL/kg)', fontsize=20)

# Boxplot for PIP Settings by Hour with 'vari_ards' distinction
sns.boxplot(ax=ax2, x='Time_Stamp_2', y='PIP_Settings', 
            hue='vari_ards', data=df, palette=colors, showfliers=False)

# Add threshold line for PIP Settings = 28
ax2.axhline(y=28, color='r', linestyle='--', linewidth=1, label='PIP Settings = 28 cmH2O')

# Adding legend for the markers
ax2.legend(bbox_to_anchor=(1, 1), loc='upper left', fontsize=20)

# Add a title for the boxplot
ax2.set_title('PIP Settings by Hour with ARDS Distinction', pad=18, fontsize=28)  # Increase pad to adjust title position

# Title and labels for the boxplot
ax2.set_ylabel('PIP Settings (cmH2O)', fontsize=20)
ax2.set_xlabel('Time', fontsize=20)

# Create custom labels for the x-axis
custom_labels = df['Time_Stamp_2'].unique()
custom_labels = sorted(custom_labels, key=lambda x: int(x[1:]))

# Set custom x-axis labels (bottom x-axis)
ax2.set_xticks(range(len(custom_labels)))
ax2.set_xticklabels(custom_labels)
ax2.tick_params(axis='x', labelsize=18)
ax2.tick_params(axis='y', labelsize=18)

# # Adjust layout
# plt.tight_layout()

# # Show plot
# plt.show()

# Save the plot as an image file
plot_filename = f"{output_dir}/Figure1.png"
# Save the plot as an image file with bbox_inches set to 'tight'
plt.savefig(plot_filename, bbox_inches='tight', dpi=600)
plt.close()  # Close the figure to avoid overlap

# %%
# Figure 2
# Describe the TV SD and the portion above 8 kg/mL

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os

output_dir = '/nfs/turbo/med-kayvan-lab/Projects/PARDS/04-Results/PARDS_Descriptive'
os.makedirs(output_dir, exist_ok=True)

# Separate the data based on 'vari_ards'
ards_data = pards_descriptive_df[pards_descriptive_df['vari_ards'] == 1]['TV(mL/kg)_ma']
non_ards_data = pards_descriptive_df[pards_descriptive_df['vari_ards'] == 0]['TV(mL/kg)_ma']

# Calculate mean, standard deviation, and the portion above 8
ards_mean = ards_data.mean()
ards_std = ards_data.std()
ards_above_8 = (ards_data > 8).sum() / len(ards_data)

non_ards_mean = non_ards_data.mean()
non_ards_std = non_ards_data.std()
non_ards_above_8 = (non_ards_data > 8).sum() / len(non_ards_data)

# Define dark blue and light gray colors
colors = ['#1f77b4', '#d3d3d3']  # Dark blue and light gray

# Plot the distributions
plt.figure(figsize=(20, 15))
sns.histplot(ards_data, color=colors[0], label='ARDS', kde=True, stat="density")
sns.histplot(non_ards_data, color=colors[1], label='Non-ARDS', kde=True, stat="density")

# Mark the mean and standard deviation
plt.axvline(ards_mean, color=colors[0], linestyle='solid', linewidth=1)
plt.axvline(ards_mean + ards_std, color=colors[0], linestyle='dashed', linewidth=1)
plt.axvline(ards_mean - ards_std, color=colors[0], linestyle='dashed', linewidth=1)
plt.axvline(non_ards_mean, color='gray', linestyle='solid', linewidth=1)
plt.axvline(non_ards_mean + non_ards_std, color='gray', linestyle='dashed', linewidth=1)
plt.axvline(non_ards_mean - non_ards_std, color='gray', linestyle='dashed', linewidth=1)

# Mark the portion where TV > 8
plt.axvline(8, color='red', linestyle='solid', linewidth=1, label='TV = 8 mL/kg')
plt.axvspan(8, ards_data.max(), color=colors[0], alpha=0.1, label='ARDS TV > 8 mL/kg')
plt.axvspan(8, non_ards_data.max(), color='gray', alpha=0.1, label='Non-ARDS TV > 8 mL/kg')

# Annotate mean and std values
plt.text(ards_mean, plt.ylim()[1]*0.9, 
         f'ARDS TV Mean: {ards_mean:.2f} mL/kg\nARDS TV Std: {ards_std:.2f} mL/kg\nARDS TV > 8 mL/kg: {ards_above_8*100:.2f}%', 
         color=colors[0], fontsize=20, fontweight='bold')
plt.text(non_ards_mean, plt.ylim()[1]*0.8, 
         f'Non-ARDS TV Mean: {non_ards_mean:.2f} mL/kg\nNon-ARDS TV Std: {non_ards_std:.2f} mL/kg\nNon-ARDS TV > 8 mL/kg: {non_ards_above_8*100:.2f}%', 
         color='gray', fontsize=20, fontweight='bold')

# Set x-axis to start from 0
plt.xlim(left=0)

# Adding legends and labels
plt.legend(bbox_to_anchor=(1, 1), loc='upper left', fontsize=20)
plt.title('Distribution of Tidal Volume (TV) Separated by ARDS Status', fontsize=28)
plt.xlabel('Tidal Volume (TV) (mL/kg)', fontsize=24)
plt.ylabel('Density', fontsize=24)

plt.tick_params(axis='x', labelsize=20)
plt.tick_params(axis='y', labelsize=20)

# plt.show()

# Save the plot as an image file
plot_filename = f"{output_dir}/Figure2.png"
# Save the plot as an image file with bbox_inches set to 'tight'
plt.savefig(plot_filename, bbox_inches='tight', dpi=600)
plt.close()  # Close the figure to avoid overlap

# %%
# Figure 3
# Individual TV variance
import pandas as pd
import matplotlib.pyplot as plt
import os

# Define the output directory (you can change this path)
output_dir = '/nfs/turbo/med-kayvan-lab/Projects/PARDS/04-Results/PARDS_Descriptive/Figure3_Individual_Tidal_Volume'
os.makedirs(output_dir, exist_ok=True)

# # Define the desired order of Time_Stamp values starting from H9 to H24
# time_order = ['H9', 'H10', 'H11', 'H12', 'H13', 'H14', 'H15', 'H16', 'H17', 'H18', 'H19', 'H20', 
#               'H21', 'H22', 'H23', 'H24', 'H1', 'H2', 'H3', 'H4', 'H5', 'H6', 'H7', 'H8']

# # Convert Time_Stamp to a categorical type with the specified order
# pards_descriptive_df['Time_Stamp_2'] = pd.Categorical(pards_descriptive_df['Time_Stamp_2'], categories=time_order, ordered=True)

# Create custom labels for the x-axis
custom_labels = pards_descriptive_df['Time_Stamp_2'].unique()
custom_labels = sorted(custom_labels, key=lambda x: int(x[1:]))

# Get unique Source_Files
unique_files = pards_descriptive_df['Source_File'].unique()

# Define dark blue and light gray colors
colors = ['#1f77b4', 'gray']  # Dark blue and light gray

# List to store the Source_File, PID, vari_ards, and average TV at 8 AM (H9)
file_stats = []
files_with_zero_out_of_range = []

# Calculate the average TV at H9 for each file
for file in unique_files:
    df_file = pards_descriptive_df[pards_descriptive_df['Source_File'] == file]
    value_at_8am = df_file[df_file['Time_Stamp_2'] == 'H9']['TV(mL/kg)_ma'].mean()
    pid = df_file['PID'].unique().astype(int)
    vari_ards = df_file['vari_ards'].iloc[0]  # Get ARDS status (assumes it’s the same within the file)
    
    # Define thresholds
    threshold_upper = round(value_at_8am + 2, 2)
    threshold_lower = round(value_at_8am - 2, 2)
    
    # Calculate the portion of time where TV is out of range
    out_of_range = df_file[(df_file['TV(mL/kg)_ma'] > threshold_upper) | (df_file['TV(mL/kg)_ma'] < threshold_lower)]
    total_time_points = len(df_file)
    portion_out_of_range = len(out_of_range) / total_time_points * 100  # Calculate as a percentage
    
    # Check if portion out of range is zero
    if portion_out_of_range == 0:
        files_with_zero_out_of_range.append(file)
        continue  # Skip plotting and saving for this file
    
    file_stats.append((file, pid, vari_ards, value_at_8am, portion_out_of_range))

# Sort by vari_ards (ARDS first), then by average TV at H9 (from low to high), then portion_out_of_range in descending order
file_stats.sort(key=lambda x: (-x[2], x[3], -x[4]))

# Iterate over the sorted list to create plots in the desired order
for file, pid, vari_ards, value_at_8am, portion_out_of_range in file_stats:
    df_file = pards_descriptive_df[pards_descriptive_df['Source_File'] == file]
    value_at_8am = round(value_at_8am, 2)
    
    # Define thresholds
    threshold_upper = round(value_at_8am + 2, 2)
    threshold_lower = round(value_at_8am - 2, 2)
    
    # Create the plot
    plt.figure(figsize=(12, 6))
    
    # Plot with different colors based on vari_ards
    for vari_ards_value in [1, 0]:  # Iterate over 0 and 1 to plot both categories
        subset = df_file[df_file['vari_ards'] == vari_ards_value]
        color = colors[0] if vari_ards_value == 1 else colors[1]
        label = 'ARDS' if vari_ards_value == 1 else 'Non-ARDS'
        
        plt.plot(subset['Time_Stamp_2'].astype(str), subset['TV(mL/kg)_ma'], 'o', 
                 color=color, label=label)
    
    # Add horizontal lines with thicker linewidth
    plt.axhline(y=threshold_upper, color='r', linestyle='--', linewidth=3, 
                label=f'Average TV at 8 am + 2 mL/kg')
    plt.axhline(y=value_at_8am, color='r', linestyle='-', linewidth=3)
    plt.axhline(y=threshold_lower, color='r', linestyle='--', linewidth=3, 
                label=f'Average TV at 8 am - 2 mL/kg')

    # Annotate the value_at_8am and thresholds on the plot with bold text
    plt.text(1, value_at_8am, f'Average TV at 8 am: {value_at_8am} mL/kg', color='red', 
            fontsize=24, weight='bold', verticalalignment='bottom', horizontalalignment='left')
    plt.text(len(custom_labels) - 1, 24.5, f'Out of range: {portion_out_of_range:.2f}%', color='red', 
            fontsize=24, weight='bold', verticalalignment='top', horizontalalignment='right')


    # Add thresholds for Volume
    plt.axhline(y=6, color='g', linestyle='--', linewidth=1, label='Tidal Volume = 6 mL/kg')
    plt.axhline(y=8, color='g', linestyle='--', linewidth=1, label='Tidal Volume = 8 mL/kg')
    
    # Add light green background between the two lines
    plt.axhspan(ymin=6, ymax=8, color='lightgreen', alpha=0.3)

    # Set x-axis to start from H9
    plt.xticks(ticks=range(len(custom_labels)), labels=custom_labels, rotation=45, ha='right')
    plt.xlim(left=-0.5, right=len(custom_labels) - 0.5)
    plt.tick_params(axis='x', labelsize=18)
    plt.tick_params(axis='y', labelsize=18)

    # Customize tick label color: make 'H9' red
    ax = plt.gca()  # Get the current axis
    for label in ax.get_xticklabels():
        if label.get_text() == 'H9':
            label.set_color('red')  # Set 'H9' label to red
    
    # Set y-axis range from 0 to 25
    plt.ylim(0, 25)
    
    # plt.title('Tidal Volume (TV) Across Time for Individual Patient', fontsize=24)
    # plt.xlabel('Time', fontsize=20)
    # plt.ylabel('Tidal Volume (TV) (mL/kg)', fontsize=20)
    
    # Place the legend outside the plot area, top-right
    # plt.legend(bbox_to_anchor=(1.1, 1), loc='upper left', fontsize=16)
    
    plt.grid(True, axis='x')  # Show only vertical grid lines
    plt.grid(False, axis='y')  # Hide horizontal grid lines
    
    # plt.show()  # Uncomment this line if you want to display the plot
    
    # Save the plot as an image file
    plot_filename = f"{output_dir}/{vari_ards}_{file.replace('.csv', '')}_{pid[0]}_({portion_out_of_range:.2f}%).png"
    # Save the plot as an image file with bbox_inches set to 'tight'
    plt.savefig(plot_filename, bbox_inches='tight', dpi=600)

    plt.close()  # Close the figure to avoid overlap

# Print the list of files with zero out-of-range portion
print("Files with zero out-of-range portion:")
for file in files_with_zero_out_of_range:
    print(file)
# Out:
# Files with zero out-of-range portion:
# a_58_CDGR_39_24hrs (27).csv
# a_58_CDGR_39_24hrs (1).csv
# a_58_CDGR_39_24hrs (28).csv
# a_58_AVEAA_4_24hrs (2).csv
# b_151_AVEAA_4_24hrs (4).csv
# a_58_AVEAA_4_24hrs (1).csv
# a_58_AVEAA_4_24hrs (3).csv

# %%
# Save Title as a Separate Image
# Create a figure for the title
fig_title = plt.figure(figsize=(12, 2))
plt.text(0.5, 0.5, 'Tidal Volume (TV) Across Time for Individual Patient', 
         ha='center', va='center', fontsize=32)
plt.axis('off')  # Hide the axis

# plt.show()  # Uncomment this line if you want to display the plot

title_filename = f"{output_dir}/title.png"
plt.savefig(title_filename, bbox_inches='tight', dpi=600)
plt.close(fig_title)

# %%
# Save X-Label as a Separate Image
# Create a figure for the x-label
fig_xlabel = plt.figure(figsize=(12, 2))
plt.text(0.5, 0.5, 'Time', ha='center', va='center', fontsize=24)
plt.axis('off')  # Hide the axis

# plt.show()  # Uncomment this line if you want to display the plot

xlabel_filename = f"{output_dir}/xlabel.png"
plt.savefig(xlabel_filename, bbox_inches='tight', dpi=600)
plt.close(fig_xlabel)

# %%
# Save Y-Label as a Separate Image
# Create a figure for the y-label
fig_ylabel = plt.figure(figsize=(2, 6))
plt.text(0.5, 0.5, 'Tidal Volume (TV) (mL/kg)', ha='center', va='center', fontsize=24, rotation=90)
plt.axis('off')  # Hide the axis

# plt.show()  # Uncomment this line if you want to display the plot

ylabel_filename = f"{output_dir}/ylabel.png"
plt.savefig(ylabel_filename, bbox_inches='tight', dpi=600)
plt.close(fig_ylabel)

# %%
# Save Legend as a Separate Image
# Create a figure for the legend
fig_legend = plt.figure(figsize=(4, 4))

# Create a dummy plot to extract the legend
fig, ax = plt.subplots()

# Manually create the legend entries without plotting them
ax.plot([], [], 'o', label='ARDS', color=colors[0])
ax.plot([], [], 'o', label='Non-ARDS', color=colors[1])
ax.plot([], [], linestyle='--', color='r', label='Average TV at 8 am + 2 mL/kg')
ax.plot([], [], linestyle='--', color='r', label='Average TV at 8 am - 2 mL/kg')
ax.plot([], [], linestyle='--', color='g', label='Tidal Volume = 6 mL/kg')
ax.plot([], [], linestyle='--', color='g', label='Tidal Volume = 8 mL/kg')

# Create the legend
legend = ax.legend(loc='center', fontsize=28)

plt.axis('off')  # Hide the axis
# plt.show()  # Uncomment this line if you want to display the plot

# Uncomment these lines if you want to save the legend as an image
legend_filename = f"{output_dir}/legend.png"
plt.savefig(legend_filename, bbox_inches='tight', dpi=600)
plt.close(fig_legend)
plt.close(fig)  # Close the dummy figure

# %%
# Supplementary Table 1
# Create a list to store all file statistics, including those with zero out-of-range portions
all_file_stats = []

# Calculate the average TV at H9 for each file
for file in unique_files:
    df_file = pards_descriptive_df[pards_descriptive_df['Source_File'] == file]
    value_at_8am = df_file[df_file['Time_Stamp_2'] == 'H9']['TV(mL/kg)_ma'].mean()
    pid = df_file['PID'].unique().astype(int)
    vari_ards = df_file['vari_ards'].iloc[0]  # Get ARDS status (assumes it’s the same within the file)
    
    # Define thresholds
    threshold_upper = round(value_at_8am + 2, 2)
    threshold_lower = round(value_at_8am - 2, 2)
    
    # Calculate the portion of time where TV is out of range
    out_of_range = df_file[(df_file['TV(mL/kg)_ma'] > threshold_upper) | (df_file['TV(mL/kg)_ma'] < threshold_lower)]
    total_time_points = len(df_file)
    portion_out_of_range = len(out_of_range) / total_time_points * 100  # Calculate as a percentage

    # Add file statistics to the list (including those with zero out-of-range)
    all_file_stats.append((file, pid, vari_ards, value_at_8am, portion_out_of_range))
    
    # Skip plotting for zero out-of-range files but still save their stats
    if portion_out_of_range == 0:
        files_with_zero_out_of_range.append(file)
        continue

    file_stats.append((file, pid, vari_ards, value_at_8am, portion_out_of_range))

# Convert the all_file_stats list into a DataFrame
file_stats_df = pd.DataFrame(all_file_stats, columns=['Source_File', 'PID', 'vari_ards', 'Avg_TV_at_8am', 'Portion_Out_of_Range'])

# Optionally, you can print the DataFrame or inspect it
print(file_stats_df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 57 entries, 0 to 56
# Data columns (total 5 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Source_File           57 non-null     object
#  1   PID                   57 non-null     object
#  2   vari_ards             57 non-null     int64
#  3   Avg_TV_at_8am         51 non-null     float64
#  4   Portion_Out_of_Range  57 non-null     float64
# dtypes: float64(2), int64(1), object(2)
# memory usage: 2.4+ KB
# None

# %%
# Supplementary Table 1 (Cont'd)
import os

# Define the output directory (you can change this path)
output_dir = '/nfs/turbo/med-kayvan-lab/Projects/PARDS/04-Results/PARDS_Descriptive'
os.makedirs(output_dir, exist_ok=True)

# Convert the all_file_stats list into a DataFrame
file_stats_df = pd.DataFrame(all_file_stats, columns=['Source_File', 'PID', 'vari_ards', 'Avg_TV_at_8am', 'Portion_Out_of_Range'])

# Round 'Avg_TV_at_8am' and 'Portion_Out_of_Range' to two decimal places
file_stats_df['Avg_TV_at_8am'] = file_stats_df['Avg_TV_at_8am'].round(2)
file_stats_df['Portion_Out_of_Range'] = file_stats_df['Portion_Out_of_Range'].round(2)

# Sort by vari_ards first (ARDS=1 first, Non-ARDS=0 second), then by Portion_Out_of_Range from high to low
file_stats_df = file_stats_df.sort_values(by=['vari_ards', 'Portion_Out_of_Range'], ascending=[False, False])

# Reset index to assign sequential numbers for the new naming column
file_stats_df = file_stats_df.reset_index(drop=True)

# Add a new column to name ARDS and Non-ARDS patients sequentially
file_stats_df['Patient_Group'] = None  # Create an empty column

# Add names for ARDS patients (vari_ards=1)
ards_mask = file_stats_df['vari_ards'] == 1
file_stats_df.loc[ards_mask, 'Patient_Group'] = ['ARDS_P' + str(i) for i in range(1, ards_mask.sum() + 1)]

# Add names for Non-ARDS patients (vari_ards=0)
non_ards_mask = file_stats_df['vari_ards'] == 0
file_stats_df.loc[non_ards_mask, 'Patient_Group'] = ['Non-ARDS_P' + str(i) for i in range(1, non_ards_mask.sum() + 1)]

# Save the DataFrame to a CSV file (or any format you prefer)
output_csv_path = f"{output_dir}/Supplementary_Table1.csv"
file_stats_df.to_csv(output_csv_path, index=False)

# Optionally, you can print the DataFrame or inspect it
print(file_stats_df.info())  # To inspect first 30 rows, including ARDS and Non-ARDS patients
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 57 entries, 0 to 56
# Data columns (total 6 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Source_File           57 non-null     object
#  1   PID                   57 non-null     object
#  2   vari_ards             57 non-null     int64
#  3   Avg_TV_at_8am         51 non-null     float64
#  4   Portion_Out_of_Range  57 non-null     float64
#  5   Patient_Group         57 non-null     object
# dtypes: float64(2), int64(1), object(3)
# memory usage: 2.8+ KB
# None

# %%
# Individual TV Stats Summary
import pandas as pd

# Convert list to DataFrame
file_stats_df = pd.DataFrame(file_stats, columns=['Source_File', 'PID', 'vari_ards', 'TV_at_8am', 'portion_out_of_range'])

# # Calculate mean and standard deviation for the entire dataset
# overall_mean = file_stats_df['portion_out_of_range'].mean()
# overall_sd = file_stats_df['portion_out_of_range'].std()

# print(f"Overall Mean of portion_out_of_range: {overall_mean:.2f}")
# print(f"Overall Standard Deviation of portion_out_of_range: {overall_sd:.2f}\n")

# # Group by 'vari_ards'
# grouped = file_stats_df.groupby('vari_ards')

# # Display each group sorted by 'portion_out_of_range' in descending order
# for name, group in grouped:
#     group_mean = group['portion_out_of_range'].mean()
#     group_sd = group['portion_out_of_range'].std()
    
#     print(f"Group: vari_ards = {name}")
#     print(f"Mean of portion_out_of_range: {group_mean:.2f}")
#     print(f"Standard Deviation of portion_out_of_range: {group_sd:.2f}")
#     print(group.sort_values(by='portion_out_of_range', ascending=False))
#     print("\n")

# %%
# Calculate the portion of time where TV is out of range for each patient
# Convert to DataFrame for easier calculations
out_of_range_df = pd.DataFrame(file_stats, columns=['File', 'PID', 'vari_ards', 'Values_at_8am', 'portion_out_of_range'])

# Function to calculate required statistics
def calculate_stats(data):
    stats = {
        'mean': data.mean(),
        'std': data.std(),
        'max': data.max(),
        'min': data.min(),
        'median': data.median()
    }
    return stats

# Calculate stats for all patients
all_stats = calculate_stats(out_of_range_df['portion_out_of_range'])

# Calculate stats for ARDS cohort
ards_stats = calculate_stats(out_of_range_df[out_of_range_df['vari_ards'] == 1]['portion_out_of_range'])

# Calculate stats for non-ARDS cohort
non_ards_stats = calculate_stats(out_of_range_df[out_of_range_df['vari_ards'] == 0]['portion_out_of_range'])

# Display the results
all_stats_label = f"All Patients: {all_stats}"
ards_stats_label = f"ARDS Patients: {ards_stats}"
non_ards_stats_label = f"Non-ARDS Patients: {non_ards_stats}"

all_stats_label, ards_stats_label, non_ards_stats_label
# Out:
# ("All Patients: {'mean': 30.262221940116266, 'std': 22.6838262228426, 'max': 93.5129076324915, 'min': 0.5455595404534679, 'median': 25.99097939497215}",
#  "ARDS Patients: {'mean': 27.844418922259432, 'std': 23.142384647976574, 'max': 93.5129076324915, 'min': 2.5490073276132024, 'median': 22.603432424149556}",
#  "Non-ARDS Patients: {'mean': 31.74410120912532, 'std': 22.652327779836263, 'max': 83.92727497412608, 'min': 0.5455595404534679, 'median': 28.735998470387663}")

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Define the desired order of Time_Stamp values starting from 8am to 7am
time_order = ['8am', '9am', '10am', '11am', '12pm', '1pm', '2pm', '3pm', '4pm', '5pm', '6pm', '7pm', 
              '8pm', '9pm', '10pm', '11pm', '12am', '1am', '2am', '3am', '4am', '5am', '6am', '7am']

# Convert Time_Stamp to a categorical type with the specified order
pards_descriptive_df['Time_Stamp'] = pd.Categorical(pards_descriptive_df['Time_Stamp'], categories=time_order, ordered=True)

# Get unique Source_Files
unique_files = pards_descriptive_df['Source_File'].unique()

# Initialize a dictionary to store value_at_8am for each PID and Source_File
pid_value_at_8am = {}

# Iterate over each unique Source_File to calculate and store value_at_8am for each PID
for file in unique_files:
    # Filter data for the current Source_File
    df_file = pards_descriptive_df[pards_descriptive_df['Source_File'] == file]
    
    # Get the TV(mL/kg)_ma value at 8 AM
    value_at_8am = df_file[df_file['Time_Stamp'] == '8am']['TV(mL/kg)_ma'].mean()
    value_at_8am = round(value_at_8am, 2)
    
    # Extract the 'PID' column as a Series and get unique values
    pid = df_file['PID'].unique().astype(int)[0]
    
    # Store the value_at_8am in the dictionary with the (PID, Source_File) tuple
    if value_at_8am in pid_value_at_8am:
        pid_value_at_8am[value_at_8am].append((pid, file))
    else:
        pid_value_at_8am[value_at_8am] = [(pid, file)]

# Filter and print PIDs and Source_Files that have the same value_at_8am
for value, pid_file_list in pid_value_at_8am.items():
    if len(pid_file_list) > 1:
        print(f'Value at 8 AM: {value}')
        for pid, file in pid_file_list:
            print(f'  PID: {pid}, Source_File: {file}')
# Out:
# Value at 8 AM: 11.28
#   PID: 178556, Source_File: a_58_CDGR_39_24hrs (14).csv
#   PID: 1025114, Source_File: a_58_CDGR_39_24hrs (39).csv

# %%
# Supplementary Figure 1
import os
import os
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# Define the output directory for saving the plots
output_dir = '/nfs/turbo/med-kayvan-lab/Projects/PARDS/04-Results/PARDS_Descriptive/Supplementary_Figure1'
os.makedirs(output_dir, exist_ok=True)

# Get the list of unique source files
unique_source_files = pards_descriptive_df['Source_File'].unique()

# Loop through each unique source file and create plots
for source_file in unique_source_files:
    # Filter the dataframe for the specific source file and make a copy
    df = pards_descriptive_df[pards_descriptive_df['Source_File'] == source_file].copy()

    # Convert PIP_Settings to integers if necessary, and drop rows where PIP_Settings is NaN
    df = df.dropna(subset=['PIP_Settings'])
    df['PIP_Settings'] = df['PIP_Settings'].astype(int)

    # Convert "Time" column to datetime if not already done
    df['Time'] = pd.to_datetime(df['Time'])

    # Filter data for the 8 AM time window (08:00 to 08:01)
    eight_am_data = df[(df['Time'].dt.time >= pd.to_datetime('08:00:00').time()) & 
                       (df['Time'].dt.time <= pd.to_datetime('08:01:00').time())]

    # Calculate average tidal volume at 8 AM
    eight_am_avg = eight_am_data['TV(mL/kg)_ma'].mean()

    # Create a title for the plot based on the "Source_File"
    # title = f"Tidal Volume and PIP Settings for {source_file}"
    title = ""

    # Create subplots with shared y-axis
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(16, 10), sharey=True)

    # Add a title for the entire figure including PID
    fig.suptitle(title, fontsize=28)

    # Violin plot
    sns.violinplot(data=df, x='PIP_Settings', y='TV(mL/kg)_ma', hue='PIP_Settings', palette='muted', ax=ax1, legend=False)
    ax1.set_xlabel('PIP Settings (cmH2O)', fontsize=20)
    ax1.set_ylabel('Tidal Volume (mL/kg)', fontsize=20)
    ax1.set_title('Tidal Volume Distribution across PIP Settings', fontsize=20)

    # Add thresholds for Volume
    ax1.axhline(y=6, color='g', linestyle='--', linewidth=1, label='Tidal Volume = 6 mL/kg')
    ax1.axhline(y=8, color='g', linestyle='--', linewidth=1, label='Tidal Volume = 8 mL/kg')

    # Add light green background between the two lines
    ax1.axhspan(ymin=6, ymax=8, color='lightgreen', alpha=0.3)

    # Get unique PIP_Settings values for the violin plot, remove NaN, and sort from smallest to largest
    unique_pip_settings = df['PIP_Settings'].dropna().unique()
    unique_pip_settings.sort()

    if not eight_am_data.empty and not np.isnan(eight_am_avg):
        # Initialize first_row_pip_settings to NaN
        first_row_pip_settings = np.nan

        # Loop through the rows in eight_am_data to find the first non-NaN "PIP_Settings" value
        for _, row in eight_am_data.iterrows():
            if not pd.isna(row['PIP_Settings']):
                first_row_pip_settings = row['PIP_Settings']
                break  # Stop once the first valid PIP_Settings value is found

        if not pd.isna(first_row_pip_settings):
            # Get the index of the first_row_pip_settings value in the unique_pip_settings list
            index_of_first_row_pip_settings = list(unique_pip_settings).index(first_row_pip_settings)

            # Plot average tidal volume at 8 am as red dot
            ax1.scatter([index_of_first_row_pip_settings], [eight_am_avg], color='red', s=50, label='Average Tidal Volume at 8 am', zorder=10)
            ax1.annotate(f'{eight_am_avg:.2f} mL/kg', xy=(index_of_first_row_pip_settings, eight_am_avg), 
                        xytext=(index_of_first_row_pip_settings + 0.2, eight_am_avg + 1),
                        arrowprops=dict(shrink=0.1, width=1.5, headwidth=8, color='red'), color='red', fontsize=28)
        
    ax1.tick_params(axis='x', labelsize=18)
    ax1.tick_params(axis='y', labelsize=18)

    # Box plot for volume at 8 am
    sns.boxplot(data=eight_am_data, x='PIP_Settings', y='TV(mL/kg)_ma', color='cyan', width=0.3, fliersize=0, ax=ax2)
    ax2.set_xlabel('PIP Settings (cmH2O)', fontsize=20)
    ax2.set_ylabel('Tidal Volume (mL/kg)', fontsize=20)
    ax2.set_title('Tidal Volume at 8 a.m. (1 minute)', fontsize=20)

    # Add thresholds for Volume
    ax2.axhline(y=6, color='g', linestyle='--', linewidth=1, label='Tidal Volume = 6 mL/kg')
    ax2.axhline(y=8, color='g', linestyle='--', linewidth=1, label='Tidal Volume = 8 mL/kg')

    # Add light green background between the two lines
    ax2.axhspan(ymin=6, ymax=8, color='lightgreen', alpha=0.3)

    ax2.tick_params(axis='x', labelsize=18)
    ax2.tick_params(axis='y', labelsize=18)

    # Move the legend outside the figure and make the plots share the same legend
    handles, labels = ax1.get_legend_handles_labels()
    fig.legend(handles, labels, bbox_to_anchor=(0.85, 0.95), loc='upper left', fontsize=20)

    plt.tight_layout(rect=[0, 0, 0.85, 1])  # Adjust layout to make space for the legend outside
    # plt.show()

    # Save the plot as an image file
    plot_filename = f"{output_dir}/{source_file.replace('.csv', '')}_Supp_Fig1_({eight_am_avg:.2f}).png"
    plt.savefig(plot_filename, bbox_inches='tight', dpi=600)
    print(f"Plot saved for {source_file} as {plot_filename}")

    plt.close()  # Close the figure to avoid overlap
# Out:
# Plot saved for a_58_CDGR_39_24hrs (12).csv as /nfs/turbo/med-kayvan-lab/Projects/PARDS/04-Results/PARDS_Descriptive/Supplementary_Figure1/a_58_CDGR_39_24hrs (12)_Supp_Fig1_(9.91).png
# Plot saved for a_58_CDGR_39_24hrs (19).csv as /nfs/turbo/med-kayvan-lab/Projects/PARDS/04-Results/PARDS_Descriptive/Supplementary_Figure1/a_58_CDGR_39_24hrs (19)_Supp_Fig1_(10.86).png
# Plot saved for a_58_CDGR_39_24hrs (35).csv as /nfs/turbo/med-kayvan-lab/Projects/PARDS/04-Results/PARDS_Descriptive/Supplementary_Figure1/a_58_CDGR_39_24hrs (35)_Supp_Fig1_(9.81).png
# Plot saved for a_58_CDGR_39_24hrs (16).csv as /nfs/turbo/med-kayvan-lab/Projects/PARDS/04-Results/PARDS_Descriptive/Supplementary_Figure1/a_58_CDGR_39_24hrs (16)_Supp_Fig1_(8.92).png
# Plot saved for b_151_CDGR_11_24hrs (4).csv as /nfs/turbo/med-kayvan-lab/Projects/PARDS/04-Results/PARDS_Descriptive/Supplementary_Figure1/b_151_CDGR_11_24hrs (4)_Supp_Fig1_(7.98).png
# ...

# %% [markdown]
# #######################################################################
#
# Double-check the patient cohort and add labels for PARDS and non-PARDS.

# %%
import pandas as pd

# Read the Excel file
excel_file = "FOCI_screening_PARDS_20240124.xlsx"
data_summary_sheet = pd.read_excel(excel_file, sheet_name="DataSummary")

# Subset the data where "Duration" == "1st"
subset_data = data_summary_sheet[data_summary_sheet["Duration"] == "1st"]

# Print the subset data
print("Subset of DataSummary sheet where Duration is 1st:")
print(subset_data.info())



# Read the CSV file
csv_file = "ards_labeled_07_02_2024.csv"
csv_data = pd.read_csv(csv_file)

print("\nData from CSV file:")
print(csv_data.info())
# Out:
# Subset of DataSummary sheet where Duration is 1st:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 58 entries, 0 to 165
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Cohort            58 non-null     object
#  1   Ventilator        58 non-null     object
#  2   Duration          58 non-null     object
#  3   File Name #       58 non-null     float64
#  4   Patient #         58 non-null     float64
#  5   48hrs Raw File #  58 non-null     float64
#  6   Patient ID        58 non-null     float64
#  7   MRN               58 non-null     float64
#  8   Time Start        57 non-null     datetime64[ns]
#  9   Time Stop         57 non-null     datetime64[ns]
#  10  Note              3 non-null      object
# dtypes: datetime64[ns](2), float64(5), object(4)
# memory usage: 5.4+ KB
# None
#
# Data from CSV file:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 69 entries, 0 to 68
# ...

# %%
# Mark duplicated rows in csv_data by adding a new column
csv_data['is_duplicate'] = csv_data['mrn'].duplicated()

# Save the final merged dataframe to a new CSV file
output_file = "ards_labeled_07_02_2024_new.csv"
csv_data.to_csv(output_file, index=False)

print(f"Final merged data has been saved to {output_file}")
# Out:
# Final merged data has been saved to ards_labeled_07_02_2024_new.csv

# %%
# Mark duplicated rows in subset_data by adding a new column
subset_data['is_duplicate'] = subset_data['MRN'].duplicated()

# Save the final merged dataframe to a new CSV file
output_file = "DataSummary_New.csv"
subset_data.to_csv(output_file, index=False)

print(f"Final merged data has been saved to {output_file}")
# Out:
# Final merged data has been saved to DataSummary_New.csv
# /tmp/ipykernel_850063/3292998136.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   subset_data['is_duplicate'] = subset_data['MRN'].duplicated()

# %%
# Merge the subset data with the CSV data on the MRN/mrn column
merged_data = pd.merge(subset_data[['Cohort', 'Ventilator', 'Patient ID', 'MRN']], csv_data[['mrn', 'vari_date', 'vari_ards', 'vari_age', 'vari_age_years']], left_on='MRN', right_on='mrn', how='outer')
merged_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 74 entries, 0 to 73
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Cohort          74 non-null     object
#  1   Ventilator      74 non-null     object
#  2   Patient ID      74 non-null     float64
#  3   MRN             74 non-null     float64
#  4   mrn             74 non-null     int64
#  5   vari_date       74 non-null     object
#  6   vari_ards       74 non-null     int64
#  7   vari_age        74 non-null     int64
#  8   vari_age_years  74 non-null     float64
# dtypes: float64(3), int64(3), object(3)
# memory usage: 5.8+ KB

# %%
import pandas as pd

# Paths to the files
csv_file_2 = "/nfs/turbo/med-kayvan-lab/Projects/PARDS/02-Data/02-EVENTS/PvsV_24hrs_Raw/Mode_Cat_CDGR.csv"
csv_file_3 = "/nfs/turbo/med-kayvan-lab/Projects/PARDS/02-Data/02-EVENTS/PvsV_24hrs_Raw/Mode_Cat_AVEAA.csv"

# Read the CSV files
csv_data_2 = pd.read_csv(csv_file_2)
csv_data_3 = pd.read_csv(csv_file_3)

print(csv_data_2.info())
print(csv_data_3.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49 entries, 0 to 48
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   PID            49 non-null     int64
#  1   File Name      49 non-null     object
#  2   File Name 2    49 non-null     object
#  3   Mode Category  49 non-null     object
#  4   Source_File    49 non-null     object
# dtypes: int64(1), object(4)
# memory usage: 2.0+ KB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   PID            8 non-null      int64
#  1   File Name      8 non-null      object
#  2   File Name 2    8 non-null      object
#  3   Mode Category  8 non-null      object
#  4   Source_File    8 non-null      object
# dtypes: int64(1), object(4)
# memory usage: 448.0+ bytes
# None

# %%
# Concatenate csv_data_2 and csv_data_3 by columns
concatenated_data = pd.concat([csv_data_2, csv_data_3], axis=0)
print(concatenated_data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 57 entries, 0 to 7
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   PID            57 non-null     int64
#  1   File Name      57 non-null     object
#  2   File Name 2    57 non-null     object
#  3   Mode Category  57 non-null     object
#  4   Source_File    57 non-null     object
# dtypes: int64(1), object(4)
# memory usage: 2.7+ KB
# None

# %%
# Merge merged_data with concatenated_data by PID
merged_data_1 = pd.merge(merged_data, concatenated_data, left_on='Patient ID', right_on='PID', how='outer')
merged_data_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 80 entries, 0 to 79
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Cohort          80 non-null     object
#  1   Ventilator      80 non-null     object
#  2   Patient ID      80 non-null     float64
#  3   MRN             80 non-null     float64
#  4   mrn             80 non-null     int64
#  5   vari_date       80 non-null     object
#  6   vari_ards       80 non-null     int64
#  7   vari_age        80 non-null     int64
#  8   vari_age_years  80 non-null     float64
#  9   PID             80 non-null     int64
#  10  File Name       80 non-null     object
#  11  File Name 2     80 non-null     object
#  12  Mode Category   80 non-null     object
#  13  Source_File     80 non-null     object
# dtypes: float64(3), int64(4), object(7)
# memory usage: 9.4+ KB

# %%
import pandas as pd

# Paths to the files
csv_file_4 = "/nfs/turbo/med-kayvan-lab/Projects/PARDS/02-Data/02-EVENTS/PvsV_24hrs_Raw/Weights_CDGR.csv"
csv_file_5 = "/nfs/turbo/med-kayvan-lab/Projects/PARDS/02-Data/02-EVENTS/PvsV_24hrs_Raw/Weights_AVEAA.csv"

# Read the CSV files
csv_data_4 = pd.read_csv(csv_file_4)
csv_data_5 = pd.read_csv(csv_file_5)

print(csv_data_4.info())
print(csv_data_5.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   patient_id     50 non-null     int64
#  1   average_value  50 non-null     float64
#  2   Source_File    50 non-null     object
# dtypes: float64(1), int64(1), object(1)
# memory usage: 1.3+ KB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   patient_id     8 non-null      int64
#  1   average_value  8 non-null      float64
#  2   Source_File    8 non-null      object
# dtypes: float64(1), int64(1), object(1)
# memory usage: 320.0+ bytes
# None

# %%
# Concatenate csv_data_4 and csv_data_5 by columns
concatenated_data_2 = pd.concat([csv_data_4, csv_data_5], axis=0)
print(concatenated_data_2.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 58 entries, 0 to 7
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   patient_id     58 non-null     int64
#  1   average_value  58 non-null     float64
#  2   Source_File    58 non-null     object
# dtypes: float64(1), int64(1), object(1)
# memory usage: 1.8+ KB
# None

# %%
# Merge merged_data_1 with concatenated_data by PID
final_merged_data = pd.merge(merged_data_1, concatenated_data_2, left_on='Patient ID', right_on='patient_id', how='outer')
final_merged_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 96 entries, 0 to 95
# Data columns (total 17 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Cohort          96 non-null     object
#  1   Ventilator      96 non-null     object
#  2   Patient ID      96 non-null     float64
#  3   MRN             96 non-null     float64
#  4   mrn             96 non-null     int64
#  5   vari_date       96 non-null     object
#  6   vari_ards       96 non-null     int64
#  7   vari_age        96 non-null     int64
#  8   vari_age_years  96 non-null     float64
#  9   PID             96 non-null     int64
#  10  File Name       96 non-null     object
#  11  File Name 2     96 non-null     object
#  12  Mode Category   96 non-null     object
#  13  Source_File_x   96 non-null     object
#  14  patient_id      96 non-null     int64
#  15  average_value   96 non-null     float64
#  16  Source_File_y   96 non-null     object
# ...

# %%
# Check for duplicated rows in final_merged_data
duplicated_rows = final_merged_data[final_merged_data['MRN'].duplicated()]
duplicated_rows.shape
# Out:
# (40, 17)

# %%
sum(final_merged_data['Source_File_x'] != final_merged_data['Source_File_y'])

# %%
# Mark duplicated rows in final_merged_data by adding a new column
final_merged_data['is_duplicate'] = final_merged_data['MRN'].duplicated()

# Drop duplicated columns
final_merged_data = final_merged_data.drop(columns=['Patient ID', 'mrn', 'Source_File_x', 'patient_id', 'Source_File_y'])

final_merged_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 96 entries, 0 to 95
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Cohort          96 non-null     object
#  1   Ventilator      96 non-null     object
#  2   MRN             96 non-null     float64
#  3   vari_date       96 non-null     object
#  4   vari_ards       96 non-null     int64
#  5   vari_age        96 non-null     int64
#  6   vari_age_years  96 non-null     float64
#  7   PID             96 non-null     int64
#  8   File Name       96 non-null     object
#  9   File Name 2     96 non-null     object
#  10  Mode Category   96 non-null     object
#  11  average_value   96 non-null     float64
#  12  is_duplicate    96 non-null     bool
# dtypes: bool(1), float64(3), int64(3), object(6)
# memory usage: 9.8+ KB

# %%
# New column order
new_order = ['Cohort', 'Ventilator', 'PID', 'MRN', 'vari_date', 'vari_ards', 'vari_age', 'vari_age_years', 
             'average_value', 'Mode Category', 'File Name', 'File Name 2', 'is_duplicate']

# Reassign DataFrame with new column order
final_merged_data = final_merged_data[new_order]

final_merged_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 96 entries, 0 to 95
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Cohort          96 non-null     object
#  1   Ventilator      96 non-null     object
#  2   PID             96 non-null     int64
#  3   MRN             96 non-null     float64
#  4   vari_date       96 non-null     object
#  5   vari_ards       96 non-null     int64
#  6   vari_age        96 non-null     int64
#  7   vari_age_years  96 non-null     float64
#  8   average_value   96 non-null     float64
#  9   Mode Category   96 non-null     object
#  10  File Name       96 non-null     object
#  11  File Name 2     96 non-null     object
#  12  is_duplicate    96 non-null     bool
# dtypes: bool(1), float64(3), int64(3), object(6)
# memory usage: 9.8+ KB

# %%
# Rename columns
final_merged_data = final_merged_data.rename(columns={'vari_age': 'vari_age_months', 
                                                      'average_value': 'vari_weight'})

final_merged_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 96 entries, 0 to 95
# Data columns (total 13 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Cohort           96 non-null     object
#  1   Ventilator       96 non-null     object
#  2   PID              96 non-null     int64
#  3   MRN              96 non-null     float64
#  4   vari_date        96 non-null     object
#  5   vari_ards        96 non-null     int64
#  6   vari_age_months  96 non-null     int64
#  7   vari_age_years   96 non-null     float64
#  8   vari_weight      96 non-null     float64
#  9   Mode Category    96 non-null     object
#  10  File Name        96 non-null     object
#  11  File Name 2      96 non-null     object
#  12  is_duplicate     96 non-null     bool
# dtypes: bool(1), float64(3), int64(3), object(6)
# memory usage: 9.8+ KB

# %%
# Save the final merged dataframe to a new CSV file
output_file = "final_merged_data.csv"
final_merged_data.to_csv(output_file, index=False)

print(f"Final merged data has been saved to {output_file}")
# Out:
# Final merged data has been saved to final_merged_data.csv

# %%
import pandas as pd

# Load the two CSV files
ards_labeled_df = pd.read_csv('ards_labeled_07_02_2024_new.csv')
final_merged_df = pd.read_csv('EHR_data.csv')

# Display the first few rows of each DataFrame to confirm successful loading
print(ards_labeled_df.info())
print(final_merged_df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 57 entries, 0 to 56
# Data columns (total 27 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   record_id                        57 non-null     object
#  1   mrn                              57 non-null     int64
#  2   vari_date                        57 non-null     object
#  3   vari_ards                        57 non-null     int64
#  4   vari_age                         57 non-null     int64
#  5   vari_age_years                   57 non-null     float64
#  6   vari_sex                         57 non-null     int64
#  7   vari_screener_ards_oi_value      10 non-null     float64
#  8   vari_screener_ards_osi_value     18 non-null     float64
#  9   vari_screener_ards_sf_value      2 non-null      float64
#  10  vari_screener_ards_radiograph    57 non-null     int64
#  11  vari_screener_ards_lung_disease  57 non-null     int64
# ...

# %%
# Specify the columns to compare
column1 = 'vari_ards'  # column name from ards_labeled_df
column2 = 'vari_ards'  # column name from final_merged_df

# Convert the columns to sets
set1 = set(ards_labeled_df[column1])
set2 = set(final_merged_df[column2])

# Compare the sets
if set1 == set2:
    print("The columns contain the same elements.")
else:
    print("The columns contain different elements.")
    # Optionally, print the differences
    print("Elements in column1 but not in column2:", set1 - set2)
    print("Elements in column2 but not in column1:", set2 - set1)
# Out:
# The columns contain the same elements.
